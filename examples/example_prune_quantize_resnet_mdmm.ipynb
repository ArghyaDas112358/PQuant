# %% [markdown]
# ## In this tutorial we create a CNN and dataloaders, and train / prune the model.

# %%
import os
os.environ["KERAS_BACKEND"] = "torch" # Needs to be set, some pruning layers as well as the quantizers are Keras
import keras
keras.config.set_backend("torch")
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
keras.backend.set_image_data_format("channels_first")
# Out:
# /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
try:
    os.chdir("/home/das214/PQuant/MDMM-dev/src")
except:
    pass

for f in os.listdir(os.getcwd()):
    print(f)
# Out:
# pquant
# data

# %%
model = torchvision.models.resnet18()
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
model = model.to(device)

model
# Out:
# Using device: cuda
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# ## Add pruning and quantization
# To add pruning and quantization, we need a config file that defines how to do that. Let's load a config file from pquant/configs/configs_pdp.yaml. The training function we use later will add the pruning layers and quantized activations automatically using this config

# %%
from pquant import get_default_config
from IPython.display import JSON

# pruning_methods: "autosparse, cl, cs, dst, pdp, wanda, mdmm"
pruning_method = "mdmm"
config = get_default_config(pruning_method)
# Set target sparsity to 80% (20% of weights are non-zero). This parameter exists only for some pruning methods
config["pruning_parameters"]["sparsity"] = 0.8
# Check what's inside the config
JSON(config)

# %%
# config = {
#     'pruning_parameters': 
#         {
#             'pruning_method': 'mdmm',
#             'enable_pruning': True,
#             'disable_pruning_for_layers': [None],
#             'constraint_type': 'Equality',
#             'target_value': 0.0,
#             'metric_type': 'UnstructuredSparsity',
#             'target_sparsity': 0.9,
#             'rf': 1,
#             'epsilon': 0.001,
#             'scale': 10.0,
#             'damping': 1.0,
#             'use_grad': False,
#             'l0_mode': 'coarse',
#             'sparsity': 0.8
#         },
#     'quantization_parameters': 
#         {
#             'enable_quantization': False,
#             'default_integer_bits': 0.0,
#             'default_fractional_bits': 7.0,
#             'hgq_gamma': 0.0003,
#             'hgq_heterogeneous': True,
#             'layer_specific': [],
#             'use_high_granularity_quantization': False,
#             'use_real_tanh': False,
#             'use_symmetric_quantization': False
#         },
#     'training_parameters': 
#         {
#         'epochs': 200,
#         'fine_tuning_epochs': 30,
#         'pretraining_epochs': 0,
#         'pruning_first': False,
#         'rewind': 'never',
#         'rounds': 1,
#         'save_weights_epoch': -1
#         },
#  'batch_size': 128,
#  'cosine_tmax': 200,
#  'gamma': 0.1,
#  'l2_decay': 0.0001,
#  'label_smoothing': 0.0,
#  'lr': 0.01,
#  'lr_schedule': 'multistep',
#  'milestones': [75, 120],
#  'momentum': 0.9,
#  'optimizer': 'sgd',
#  'plot_frequency': 100
#  }

# %%
# Replace layers with compressed layers
from pquant import add_compression_layers
input_shape = (256,3,32,32)
model = add_compression_layers(model, config, input_shape)
model
# Out:
# ResNet(
#   (conv1): CompressedLayerConv2d(
#     (pruning_layer): <MDMM name=mdmm, built=True>
#   )
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_1, built=True>
#       )
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_2, built=True>
#       )
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_3, built=True>
#       )
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_4, built=True>
#       )
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_5, built=True>
#       )
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_6, built=True>
#       )
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): CompressedLayerConv2d(
#           (pruning_layer): <MDMM name=mdmm_7, built=True>
#         )
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_8, built=True>
#       )
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_9, built=True>
#       )
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_10, built=True>
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_11, built=True>
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): CompressedLayerConv2d(
#           (pruning_layer): <MDMM name=mdmm_12, built=True>
#         )
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_13, built=True>
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_14, built=True>
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_15, built=True>
#       )
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_16, built=True>
#       )
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): CompressedLayerConv2d(
#           (pruning_layer): <MDMM name=mdmm_17, built=True>
#         )
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_18, built=True>
#       )
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_19, built=True>
#       )
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): CompressedLayerLinear(
#     (pruning_layer): <MDMM name=mdmm_20, built=True>
#   )
# )

# %% [markdown]
# ## Pruning and quantization in the config
# From the config we see that we are using the PDP pruning method, unstructured version. We aim for 80% weights pruned (sparsity 0.8), and we quantize the model to 8 bits (1 bit goes to sign).
# By default, all convolutional and linear layers, as well as activations will be quantized using the default values ```default_integer_bits``` and ```default_fractional_bits```. Similarly, by default all convolutional and linear layers will be pruned.
#
# We can disable pruning and/or quantization by setting the enable_pruning / enable_quantization to False. To change quantization bits for a specific layer, add the layers name to the list found in ```layer_specific```, followed by number of bits. To disable pruning for a single layer, add its name to the ```disable_pruning_for_layers``` list.
#
# We'll show later how to create a custom quantization / pruning config file from an existing config for a given model

# %% [markdown]
# ## About the different epochs
#
# The config defines 20 ```pretraining_epochs```, 100 ```epochs``` and 20 ```fine_tuning_epochs```. What happens during each of these training steps is algorithm specific.
#
# In PDP, the pretraining phase consists of training without pruning, followed by calculation of layerwise pruning budgets. After pretraining is finished and the layerwise pruning budgets have been calculated, the training with pruning begins. The mask during this training is a soft mask, consisting of values ranging between (and including) 0 and 1.
#
# The fine-tuning step in PDP is optional (not mentioned in the original paper), and during it the mask is fixed and rounded to 0s and 1s.

# %% [markdown]
# ## Create data set
# #### Let's create the data loader and the training and validation loops

# %%
import torchvision.transforms as transforms

def get_cifar10_data(batch_size):
    normalize = transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    train_transform = transforms.Compose([transforms.RandomHorizontalFlip(), transforms.RandomCrop(32, padding=4), 
                                          transforms.ToTensor(), normalize])
    test_transform = transforms.Compose([transforms.ToTensor(), normalize])  
    trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=train_transform)
    valset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                       download=True, transform=test_transform)
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=4, pin_memory=True)

    val_loader = torch.utils.data.DataLoader(valset, batch_size=batch_size,
                                         shuffle=False, num_workers=4, pin_memory=True)

    return train_loader, val_loader

from quantizers.fixed_point.fixed_point_ops import get_fixed_quantizer
# Set up input quantizer
quantizer = get_fixed_quantizer(overflow_mode="SAT")


def train_resnet(model, trainloader, device, loss_func, epoch, optimizer, scheduler, *args, **kwargs):
    first_batch = True
    for data in trainloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        inputs = quantizer(inputs, k=torch.tensor(1.), i=torch.tensor(0.), f=torch.tensor(7.)) # 8 bits input quantization
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_func(outputs, labels)
        losses = get_model_losses(model, torch.tensor(0.).to(device))
        loss += losses
        loss.backward()
        
        if first_batch:
            print("\n ---- Checking Loss values ----")
            print("Loss:", loss_func(outputs, labels).item())
            print("Model Losses:", losses.item())
            print("--------------------------------------------------")
            print(f"\n--- Checking Gradients for lmbda at Epoch {epoch} ---")
            for name, module in model.named_modules():
                if "pruning_layer.constraint_layer.module" in name and hasattr(module, "lmbda"):
                    # Access the underlying tensor via the '.value' attribute
                    underlying_tensor = module.lmbda.value
                    grad_value = underlying_tensor.grad
                    print(f"Layer: {name}, lmbda: {underlying_tensor.item()}")
                    if grad_value is not None:
                        print(f"Layer: {name}, Gradient: {grad_value.item()}")
                    else:
                        print(f"Layer: {name}, Gradient: None")
                        
                    break
            print("--------------------------------------------------\n")
            first_batch = False
            
        optimizer.step()
        epoch += 1
        if scheduler is not None:
            scheduler.step()


from pquant import get_layer_keep_ratio, get_model_losses

def validate_resnet(model, testloader, device, loss_func, epoch, *args, **kwargs):
    correct = 0
    total = 0
    model.eval()
    with torch.no_grad():
        for data in testloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            inputs = quantizer(inputs, k=torch.tensor(1.), i=torch.tensor(0.), f=torch.tensor(7.)) # 8 bits input quantization
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        ratio = get_layer_keep_ratio(model)
        print(f'Accuracy: {100 * correct / total:.2f}%, remaining_weights: {ratio * 100:.2f}%')

BATCH_SIZE = 256
train_loader, val_loader = get_cifar10_data(BATCH_SIZE)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Create loss function, scheduler and optimizer

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR

optimizer = torch.optim.SGD(model.parameters(), lr=0.01, weight_decay=0.0001, momentum=0.9)
scheduler = CosineAnnealingLR(optimizer, 200)
loss_function = nn.CrossEntropyLoss()

# %% [markdown]
# ## Train model
# Training time. We use the train_compressed_model function from pquant to train. We need to provide some parameters such as training and validation functions, their input parameters, the model and the config file. The function automatically adds pruning layers and replaces activations with a quantized variant, trains the model, and removes the pruning layers after training is done

# %%
from pquant import iterative_train
"""
Inputs to train_resnet we defined previously are:
          model, trainloader, device, loss_func, epoch, optimizer, scheduler, **kwargs
"""

trained_model = iterative_train(model = model, 
                                config = config, 
                                train_func = train_resnet, 
                                valid_func = validate_resnet, 
                                trainloader = train_loader, 
                                testloader = val_loader, 
                                device = device, 
                                loss_func = loss_function,
                                optimizer = optimizer, 
                                scheduler = scheduler
                                )
# Out:
# Training Rounds:   0%|          | 0/1 [00:00<?, ?it/s]
# Epochs:   0%|          | 0/200 [00:00<?, ?it/s]
#  ---- Checking Loss values ----
# Loss: 7.510077953338623
# Model Losses: 6.166759967803955
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 0 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 1.0016295909881592
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 46.33%, remaining_weights: 96.31%
#
#  ---- Checking Loss values ----
# Loss: 1.47770094871521
# Model Losses: 13.936258316040039
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 197 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 1.6863092184066772
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 46.58%, remaining_weights: 95.80%
#
#  ---- Checking Loss values ----
# Loss: 1.484571099281311
# Model Losses: 17.7648868560791
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 394 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.1786320209503174
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 58.35%, remaining_weights: 94.88%
#
#  ---- Checking Loss values ----
# Loss: 1.0791277885437012
# Model Losses: 17.92813491821289
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 591 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.4499502182006836
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 51.79%, remaining_weights: 94.19%
#
#  ---- Checking Loss values ----
# Loss: 1.3382686376571655
# Model Losses: 18.81855583190918
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 788 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.7156925201416016
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.42%, remaining_weights: 92.72%
#
#  ---- Checking Loss values ----
# Loss: 1.1436100006103516
# Model Losses: 16.65087890625
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 985 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.9326369762420654
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 55.34%, remaining_weights: 92.11%
#
#  ---- Checking Loss values ----
# Loss: 1.2571886777877808
# Model Losses: 17.34404754638672
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1182 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.166433334350586
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.34%, remaining_weights: 90.18%
#
#  ---- Checking Loss values ----
# Loss: 0.9070832133293152
# Model Losses: 14.799396514892578
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1379 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.3615970611572266
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 49.64%, remaining_weights: 89.65%
#
#  ---- Checking Loss values ----
# Loss: 1.3745616674423218
# Model Losses: 15.631918907165527
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1576 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.5675442218780518
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.80%, remaining_weights: 87.36%
#
#  ---- Checking Loss values ----
# Loss: 0.8928700685501099
# Model Losses: 13.156414985656738
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1773 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.7396230697631836
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 51.94%, remaining_weights: 86.92%
#
#  ---- Checking Loss values ----
# Loss: 1.0760051012039185
# Model Losses: 13.923178672790527
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1970 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.9146018028259277
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.68%, remaining_weights: 84.45%
#
#  ---- Checking Loss values ----
# Loss: 0.8990007638931274
# Model Losses: 11.84267520904541
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2167 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.072683334350586
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 56.24%, remaining_weights: 84.08%
#
#  ---- Checking Loss values ----
# Loss: 1.1307066679000854
# Model Losses: 12.49860954284668
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2364 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.22761344909668
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.74%, remaining_weights: 81.48%
#
#  ---- Checking Loss values ----
# Loss: 0.9340502619743347
# Model Losses: 10.757100105285645
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2561 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.370299816131592
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 43.09%, remaining_weights: 81.19%
#
#  ---- Checking Loss values ----
# Loss: 1.2427663803100586
# Model Losses: 11.375920295715332
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2758 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.506916522979736
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.02%, remaining_weights: 78.48%
#
#  ---- Checking Loss values ----
# Loss: 1.0250482559204102
# Model Losses: 9.86430549621582
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2955 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.640994071960449
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 56.75%, remaining_weights: 78.03%
#
#  ---- Checking Loss values ----
# Loss: 1.0936179161071777
# Model Losses: 10.233390808105469
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3152 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.761829853057861
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.12%, remaining_weights: 75.43%
#
#  ---- Checking Loss values ----
# Loss: 0.9173266291618347
# Model Losses: 9.059759140014648
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3349 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.884903430938721
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 59.54%, remaining_weights: 74.90%
#
#  ---- Checking Loss values ----
# Loss: 1.0258582830429077
# Model Losses: 9.302647590637207
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3546 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.998281955718994
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.31%, remaining_weights: 72.47%
#
#  ---- Checking Loss values ----
# Loss: 1.1726808547973633
# Model Losses: 8.354935646057129
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3743 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.11787223815918
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.21%, remaining_weights: 71.78%
#
#  ---- Checking Loss values ----
# Loss: 0.9738731980323792
# Model Losses: 8.449562072753906
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3940 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.215943813323975
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.48%, remaining_weights: 69.43%
#
#  ---- Checking Loss values ----
# Loss: 0.8942742943763733
# Model Losses: 7.664738655090332
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4137 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.334273815155029
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 48.89%, remaining_weights: 68.60%
#
#  ---- Checking Loss values ----
# Loss: 1.1418485641479492
# Model Losses: 7.62851095199585
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4334 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.42721700668335
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.88%, remaining_weights: 66.51%
#
#  ---- Checking Loss values ----
# Loss: 1.0861735343933105
# Model Losses: 7.06436824798584
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4531 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.539674758911133
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.06%, remaining_weights: 65.44%
#
#  ---- Checking Loss values ----
# Loss: 0.9619858860969543
# Model Losses: 6.869851112365723
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4728 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.624398231506348
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 61.79%, remaining_weights: 63.80%
#
#  ---- Checking Loss values ----
# Loss: 0.9949963092803955
# Model Losses: 6.549330234527588
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4925 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.734910011291504
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.88%, remaining_weights: 62.44%
#
#  ---- Checking Loss values ----
# Loss: 1.0195791721343994
# Model Losses: 6.207114219665527
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5122 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.809222221374512
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.45%, remaining_weights: 61.11%
#
#  ---- Checking Loss values ----
# Loss: 1.083292007446289
# Model Losses: 6.106350421905518
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5319 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.921999454498291
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.62%, remaining_weights: 59.52%
#
#  ---- Checking Loss values ----
# Loss: 0.8516801595687866
# Model Losses: 5.611988067626953
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5516 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.990449905395508
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.33%, remaining_weights: 58.45%
#
#  ---- Checking Loss values ----
# Loss: 1.0053364038467407
# Model Losses: 5.6617536544799805
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5713 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.102072238922119
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 69.45%, remaining_weights: 56.74%
#
#  ---- Checking Loss values ----
# Loss: 0.7663530707359314
# Model Losses: 5.091058731079102
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5910 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.1667256355285645
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 61.30%, remaining_weights: 55.95%
#
#  ---- Checking Loss values ----
# Loss: 1.0701055526733398
# Model Losses: 5.258152008056641
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6107 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.272729873657227
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 69.97%, remaining_weights: 54.15%
#
#  ---- Checking Loss values ----
# Loss: 0.6885820031166077
# Model Losses: 4.649740695953369
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6304 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.331830024719238
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 59.06%, remaining_weights: 53.61%
#
#  ---- Checking Loss values ----
# Loss: 1.0431791543960571
# Model Losses: 4.916018486022949
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6501 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.439762115478516
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 74.07%, remaining_weights: 51.68%
#
#  ---- Checking Loss values ----
# Loss: 0.8197004199028015
# Model Losses: 4.240884304046631
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6698 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.496118068695068
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 56.88%, remaining_weights: 51.35%
#
#  ---- Checking Loss values ----
# Loss: 1.0427623987197876
# Model Losses: 4.634416580200195
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6895 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.605031490325928
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 75.24%, remaining_weights: 49.35%
#
#  ---- Checking Loss values ----
# Loss: 0.6935170888900757
# Model Losses: 3.8810083866119385
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7092 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.657584190368652
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 60.34%, remaining_weights: 49.13%
#
#  ---- Checking Loss values ----
# Loss: 1.103261947631836
# Model Losses: 4.28173303604126
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7289 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.758695602416992
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 76.08%, remaining_weights: 47.18%
#
#  ---- Checking Loss values ----
# Loss: 0.7516274452209473
# Model Losses: 3.5603132247924805
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7486 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.808523178100586
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.75%, remaining_weights: 47.11%
#
#  ---- Checking Loss values ----
# Loss: 1.1369112730026245
# Model Losses: 3.9855990409851074
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7683 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.903619766235352
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 76.67%, remaining_weights: 45.11%
#
#  ---- Checking Loss values ----
# Loss: 0.7512283325195312
# Model Losses: 3.2705037593841553
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7880 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.951380729675293
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.88%, remaining_weights: 45.16%
#
#  ---- Checking Loss values ----
# Loss: 1.0268042087554932
# Model Losses: 3.7394189834594727
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8077 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.046372413635254
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.74%, remaining_weights: 43.11%
#
#  ---- Checking Loss values ----
# Loss: 0.7449375987052917
# Model Losses: 3.0032286643981934
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8274 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.09532356262207
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 54.74%, remaining_weights: 43.42%
#
#  ---- Checking Loss values ----
# Loss: 0.9945690035820007
# Model Losses: 3.563936710357666
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8471 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.190095901489258
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.54%, remaining_weights: 41.24%
#
#  ---- Checking Loss values ----
# Loss: 0.6780625581741333
# Model Losses: 2.7620315551757812
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8668 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.240530490875244
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 58.98%, remaining_weights: 41.63%
#
#  ---- Checking Loss values ----
# Loss: 1.0176764726638794
# Model Losses: 3.3233494758605957
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8865 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.335870742797852
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.07%, remaining_weights: 39.47%
#
#  ---- Checking Loss values ----
# Loss: 0.7754579782485962
# Model Losses: 2.5366523265838623
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9062 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.385818004608154
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 55.82%, remaining_weights: 39.91%
#
#  ---- Checking Loss values ----
# Loss: 1.006954550743103
# Model Losses: 3.005629062652588
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9259 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.467192649841309
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.15%, remaining_weights: 37.95%
#
#  ---- Checking Loss values ----
# Loss: 0.6952845454216003
# Model Losses: 2.3544657230377197
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9456 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.520037651062012
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 60.07%, remaining_weights: 38.31%
#
#  ---- Checking Loss values ----
# Loss: 1.06477952003479
# Model Losses: 2.8512961864471436
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9653 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.6060791015625
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.46%, remaining_weights: 36.39%
#
#  ---- Checking Loss values ----
# Loss: 0.7795550227165222
# Model Losses: 2.1536693572998047
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9850 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.656805038452148
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 50.14%, remaining_weights: 36.86%
#
#  ---- Checking Loss values ----
# Loss: 1.081912875175476
# Model Losses: 2.660377025604248
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10047 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.734920501708984
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.86%, remaining_weights: 35.00%
#
#  ---- Checking Loss values ----
# Loss: 0.7421875
# Model Losses: 1.9970089197158813
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10244 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.787367343902588
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.45%, remaining_weights: 35.47%
#
#  ---- Checking Loss values ----
# Loss: 1.0898141860961914
# Model Losses: 2.4778151512145996
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10441 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.863865852355957
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 79.09%, remaining_weights: 33.69%
#
#  ---- Checking Loss values ----
# Loss: 0.7574189901351929
# Model Losses: 1.8438373804092407
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10638 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.914287090301514
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 58.12%, remaining_weights: 34.24%
#
#  ---- Checking Loss values ----
# Loss: 1.0885601043701172
# Model Losses: 2.3616552352905273
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10835 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.991123676300049
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.57%, remaining_weights: 32.46%
#
#  ---- Checking Loss values ----
# Loss: 0.662699282169342
# Model Losses: 1.7106114625930786
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11032 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.044737815856934
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.47%, remaining_weights: 32.94%
#
#  ---- Checking Loss values ----
# Loss: 0.9992998838424683
# Model Losses: 2.1951093673706055
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11229 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.119479179382324
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.35%, remaining_weights: 31.44%
#
#  ---- Checking Loss values ----
# Loss: 0.7518551349639893
# Model Losses: 1.617469072341919
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11426 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.174941062927246
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.06%, remaining_weights: 31.77%
#
#  ---- Checking Loss values ----
# Loss: 1.0210167169570923
# Model Losses: 2.010683298110962
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11623 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.238572120666504
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.52%, remaining_weights: 30.41%
#
#  ---- Checking Loss values ----
# Loss: 0.627366304397583
# Model Losses: 1.5301827192306519
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11820 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.295644760131836
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.48%, remaining_weights: 30.64%
#
#  ---- Checking Loss values ----
# Loss: 0.9986861944198608
# Model Losses: 1.8945401906967163
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12017 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.362672805786133
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.01%, remaining_weights: 29.49%
#
#  ---- Checking Loss values ----
# Loss: 0.6842567324638367
# Model Losses: 1.4631887674331665
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12214 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.424765586853027
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.56%, remaining_weights: 29.56%
#
#  ---- Checking Loss values ----
# Loss: 1.0623468160629272
# Model Losses: 1.7396559715270996
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12411 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.485742568969727
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.09%, remaining_weights: 28.66%
#
#  ---- Checking Loss values ----
# Loss: 0.6922094225883484
# Model Losses: 1.3853563070297241
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12608 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.544665336608887
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 69.62%, remaining_weights: 28.49%
#
#  ---- Checking Loss values ----
# Loss: 0.9091507792472839
# Model Losses: 1.541000247001648
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12805 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.597155570983887
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 76.96%, remaining_weights: 27.93%
#
#  ---- Checking Loss values ----
# Loss: 0.75617915391922
# Model Losses: 1.3504587411880493
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13002 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.659235000610352
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.25%, remaining_weights: 27.64%
#
#  ---- Checking Loss values ----
# Loss: 0.8972263932228088
# Model Losses: 1.4643844366073608
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13199 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.715028762817383
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 76.23%, remaining_weights: 27.26%
#
#  ---- Checking Loss values ----
# Loss: 0.703118622303009
# Model Losses: 1.3150713443756104
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13396 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.779192924499512
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.39%, remaining_weights: 26.75%
#
#  ---- Checking Loss values ----
# Loss: 0.9773546457290649
# Model Losses: 1.3184306621551514
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13593 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.828129768371582
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 75.28%, remaining_weights: 26.63%
#
#  ---- Checking Loss values ----
# Loss: 0.6649227142333984
# Model Losses: 1.2872498035430908
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13790 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.893107414245605
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 74.15%, remaining_weights: 25.99%
#
#  ---- Checking Loss values ----
# Loss: 0.7291746139526367
# Model Losses: 1.2081924676895142
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13987 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.936554908752441
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 73.60%, remaining_weights: 26.09%
#
#  ---- Checking Loss values ----
# Loss: 0.7817878127098083
# Model Losses: 1.2596369981765747
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14184 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.002358436584473
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 72.03%, remaining_weights: 25.29%
#
#  ---- Checking Loss values ----
# Loss: 0.7818784713745117
# Model Losses: 1.1098498106002808
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14381 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.043806076049805
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 71.51%, remaining_weights: 25.64%
#
#  ---- Checking Loss values ----
# Loss: 0.714465320110321
# Model Losses: 1.2631170749664307
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14578 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.109567642211914
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.74%, remaining_weights: 24.70%
#
#  ---- Checking Loss values ----
# Loss: 0.7920255064964294
# Model Losses: 1.0511962175369263
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14775 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.152390480041504
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 71.64%, remaining_weights: 25.19%
#
#  ---- Checking Loss values ----
# Loss: 0.7628422975540161
# Model Losses: 1.2697148323059082
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14972 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.223958969116211
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 73.82%, remaining_weights: 24.15%
#
#  ---- Checking Loss values ----
# Loss: 0.6831015348434448
# Model Losses: 0.967462420463562
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15169 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.261131286621094
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 69.66%, remaining_weights: 24.68%
#
#  ---- Checking Loss values ----
# Loss: 0.7552777528762817
# Model Losses: 1.2557183504104614
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15366 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.32972526550293
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.66%, remaining_weights: 23.64%
#
#  ---- Checking Loss values ----
# Loss: 0.6421695947647095
# Model Losses: 0.9030672311782837
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15563 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.363825798034668
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.15%, remaining_weights: 24.24%
#
#  ---- Checking Loss values ----
# Loss: 0.8817519545555115
# Model Losses: 1.2450413703918457
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15760 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.435256004333496
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.69%, remaining_weights: 23.19%
#
#  ---- Checking Loss values ----
# Loss: 0.677599310874939
# Model Losses: 0.8572285771369934
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15957 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.467548370361328
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.36%, remaining_weights: 23.96%
#
#  ---- Checking Loss values ----
# Loss: 0.8303388357162476
# Model Losses: 1.2474337816238403
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16154 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.534852981567383
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 80.42%, remaining_weights: 22.85%
#
#  ---- Checking Loss values ----
# Loss: 0.6293535828590393
# Model Losses: 0.83099764585495
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16351 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.566343307495117
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 70.46%, remaining_weights: 23.50%
#
#  ---- Checking Loss values ----
# Loss: 0.8517206311225891
# Model Losses: 1.2056403160095215
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16548 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.632807731628418
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 80.94%, remaining_weights: 22.41%
#
#  ---- Checking Loss values ----
# Loss: 0.5992118716239929
# Model Losses: 0.7952772974967957
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16745 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.663259506225586
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 70.78%, remaining_weights: 23.26%
#
#  ---- Checking Loss values ----
# Loss: 0.6628308296203613
# Model Losses: 1.263522744178772
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16942 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.732982635498047
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 81.00%, remaining_weights: 22.12%
#
#  ---- Checking Loss values ----
# Loss: 0.5083601474761963
# Model Losses: 0.7814820408821106
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17139 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.763182640075684
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.50%, remaining_weights: 23.05%
#
#  ---- Checking Loss values ----
# Loss: 0.8105828166007996
# Model Losses: 1.303051233291626
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17336 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.835134506225586
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 81.77%, remaining_weights: 21.85%
#
#  ---- Checking Loss values ----
# Loss: 0.5750616788864136
# Model Losses: 0.7746804356575012
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17533 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.867330551147461
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.02%, remaining_weights: 22.62%
#
#  ---- Checking Loss values ----
# Loss: 0.7963370084762573
# Model Losses: 1.2283326387405396
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17730 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.9324312210083
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.19%, remaining_weights: 21.49%
#
#  ---- Checking Loss values ----
# Loss: 0.6020602583885193
# Model Losses: 0.7543792128562927
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17927 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.96415901184082
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 68.77%, remaining_weights: 22.43%
#
#  ---- Checking Loss values ----
# Loss: 0.7954937219619751
# Model Losses: 1.2491827011108398
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18124 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.025729179382324
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.31%, remaining_weights: 21.17%
#
#  ---- Checking Loss values ----
# Loss: 0.5046976804733276
# Model Losses: 0.7360405921936035
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18321 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.058608055114746
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.19%, remaining_weights: 22.03%
#
#  ---- Checking Loss values ----
# Loss: 0.962208092212677
# Model Losses: 1.2198230028152466
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18518 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.122035026550293
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.24%, remaining_weights: 20.90%
#
#  ---- Checking Loss values ----
# Loss: 0.6254269480705261
# Model Losses: 0.7281919717788696
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18715 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.155763626098633
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 68.19%, remaining_weights: 21.76%
#
#  ---- Checking Loss values ----
# Loss: 0.8995110392570496
# Model Losses: 1.219443440437317
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18912 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.216703414916992
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.56%, remaining_weights: 20.65%
#
#  ---- Checking Loss values ----
# Loss: 0.5522568225860596
# Model Losses: 0.7245953679084778
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19109 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.252506256103516
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 61.62%, remaining_weights: 21.42%
#
#  ---- Checking Loss values ----
# Loss: 0.7989068031311035
# Model Losses: 1.2240574359893799
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19306 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.316400527954102
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.74%, remaining_weights: 20.35%
#
#  ---- Checking Loss values ----
# Loss: 0.5200344920158386
# Model Losses: 0.7006267309188843
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19503 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.352433204650879
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 68.12%, remaining_weights: 21.23%
#
#  ---- Checking Loss values ----
# Loss: 0.8306392431259155
# Model Losses: 1.193901538848877
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19700 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.409274101257324
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.83%, remaining_weights: 20.07%
#
#  ---- Checking Loss values ----
# Loss: 0.4946131706237793
# Model Losses: 0.6783630847930908
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19897 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.444546699523926
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 68.80%, remaining_weights: 20.86%
#
#  ---- Checking Loss values ----
# Loss: 0.8292203545570374
# Model Losses: 1.1409884691238403
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20094 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.499449729919434
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.81%, remaining_weights: 19.89%
#
#  ---- Checking Loss values ----
# Loss: 0.5831958055496216
# Model Losses: 0.6882975101470947
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20291 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.538509368896484
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 61.41%, remaining_weights: 20.69%
#
#  ---- Checking Loss values ----
# Loss: 0.7482338547706604
# Model Losses: 1.1983524560928345
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20488 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.59991455078125
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.90%, remaining_weights: 19.68%
#
#  ---- Checking Loss values ----
# Loss: 0.5610544681549072
# Model Losses: 0.6729631423950195
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20685 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.63842487335205
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.25%, remaining_weights: 20.30%
#
#  ---- Checking Loss values ----
# Loss: 0.8610273003578186
# Model Losses: 1.123945951461792
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20882 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.695496559143066
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.96%, remaining_weights: 19.48%
#
#  ---- Checking Loss values ----
# Loss: 0.601620614528656
# Model Losses: 0.6670682430267334
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 21079 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.735485076904297
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.20%, remaining_weights: 19.90%
#
#  ---- Checking Loss values ----
# Loss: 0.8516599535942078
# Model Losses: 0.9968999624252319
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 21276 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.78402042388916
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.54%, remaining_weights: 19.28%
#
#  ---- Checking Loss values ----
# Loss: 0.5654498338699341
# Model Losses: 0.6681734919548035
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 21473 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.82413387298584
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 61.64%, remaining_weights: 19.53%
#
#  ---- Checking Loss values ----
# Loss: 0.760989248752594
# Model Losses: 0.9137621521949768
# --------------------------------------------------
#
# ...
#
# --- Checking Gradients for lmbda at Epoch 37627 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 13.88880443572998
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 74.13%, remaining_weights: 16.22%
#
#  ---- Checking Loss values ----
# Loss: 0.590925395488739
# Model Losses: 0.9307580590248108
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 37824 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 13.929818153381348
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 89.48%, remaining_weights: 15.46%
#
#  ---- Checking Loss values ----
# Loss: 0.33305877447128296
# Model Losses: 0.562924325466156
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 38021 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 13.95654296875
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 75.72%, remaining_weights: 16.25%
#
#  ---- Checking Loss values ----
# Loss: 0.6474609375
# Model Losses: 0.9671820402145386
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 38218 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 13.997990608215332
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 89.39%, remaining_weights: 15.43%
#
#  ---- Checking Loss values ----
# Loss: 0.33402809500694275
# Model Losses: 0.5513846278190613
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 38415 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.024236679077148
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 75.47%, remaining_weights: 16.17%
#
#  ---- Checking Loss values ----
# Loss: 0.5478289127349854
# Model Losses: 0.9556291699409485
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 38612 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.064125061035156
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 89.68%, remaining_weights: 15.41%
#
#  ---- Checking Loss values ----
# Loss: 0.48766371607780457
# Model Losses: 0.5618484616279602
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 38809 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.091730117797852
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.74%, remaining_weights: 16.06%
#
#  ---- Checking Loss values ----
# Loss: 0.6130721569061279
# Model Losses: 0.948910653591156
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 39006 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.1327543258667
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 89.46%, remaining_weights: 15.37%
#
#  ---- Checking Loss values ----
# Loss: 0.3392135500907898
# Model Losses: 0.5547319650650024
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 39203 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.160492897033691
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 74.98%, remaining_weights: 16.01%
# Fine-tuning:   0%|          | 0/30 [00:00<?, ?it/s]
#  ---- Checking Loss values ----
# Loss: 0.6431273221969604
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 39400 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 89.97%, remaining_weights: 13.68%
#
#  ---- Checking Loss values ----
# Loss: 0.4734657406806946
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 39597 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 86.69%, remaining_weights: 12.75%
#
#  ---- Checking Loss values ----
# Loss: 0.39574959874153137
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 39794 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 91.66%, remaining_weights: 12.01%
#
#  ---- Checking Loss values ----
# Loss: 0.3311692476272583
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 39991 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 88.73%, remaining_weights: 11.68%
#
#  ---- Checking Loss values ----
# Loss: 0.3635793626308441
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 40188 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 92.64%, remaining_weights: 11.24%
#
#  ---- Checking Loss values ----
# Loss: 0.39711371064186096
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 40385 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 90.20%, remaining_weights: 11.07%
#
#  ---- Checking Loss values ----
# Loss: 0.3419107496738434
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 40582 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 93.31%, remaining_weights: 10.73%
#
#  ---- Checking Loss values ----
# Loss: 0.289104163646698
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 40779 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 91.08%, remaining_weights: 10.62%
#
#  ---- Checking Loss values ----
# Loss: 0.3270204961299896
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 40976 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 93.83%, remaining_weights: 10.36%
#
#  ---- Checking Loss values ----
# Loss: 0.35869652032852173
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 41173 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 91.10%, remaining_weights: 10.29%
#
#  ---- Checking Loss values ----
# Loss: 0.2303258329629898
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 41370 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 94.15%, remaining_weights: 10.06%
#
#  ---- Checking Loss values ----
# Loss: 0.22983741760253906
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 41567 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 93.35%, remaining_weights: 10.01%
#
#  ---- Checking Loss values ----
# Loss: 0.3012852966785431
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 41764 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 94.64%, remaining_weights: 9.82%
#
#  ---- Checking Loss values ----
# Loss: 0.18599951267242432
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 41961 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 93.55%, remaining_weights: 9.78%
#
#  ---- Checking Loss values ----
# Loss: 0.18840815126895905
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 42158 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 95.00%, remaining_weights: 9.61%
#
#  ---- Checking Loss values ----
# Loss: 0.26500755548477173
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 42355 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 93.71%, remaining_weights: 9.58%
#
#  ---- Checking Loss values ----
# Loss: 0.22140593826770782
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 42552 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 94.87%, remaining_weights: 9.43%
#
#  ---- Checking Loss values ----
# Loss: 0.24160565435886383
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 42749 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 94.88%, remaining_weights: 9.41%
#
#  ---- Checking Loss values ----
# Loss: 0.2053125500679016
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 42946 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 95.20%, remaining_weights: 9.27%
#
#  ---- Checking Loss values ----
# Loss: 0.29741907119750977
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 43143 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 95.71%, remaining_weights: 9.25%
#
#  ---- Checking Loss values ----
# Loss: 0.23600983619689941
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 43340 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 95.55%, remaining_weights: 9.13%
#
#  ---- Checking Loss values ----
# Loss: 0.17693506181240082
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 43537 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 95.87%, remaining_weights: 9.12%
#
#  ---- Checking Loss values ----
# Loss: 0.22565312683582306
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 43734 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 95.58%, remaining_weights: 9.00%
#
#  ---- Checking Loss values ----
# Loss: 0.21530775725841522
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 43931 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 96.44%, remaining_weights: 8.99%
#
#  ---- Checking Loss values ----
# Loss: 0.18213793635368347
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 44128 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 95.57%, remaining_weights: 8.88%
#
#  ---- Checking Loss values ----
# Loss: 0.2338387668132782
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 44325 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 96.72%, remaining_weights: 8.88%
#
#  ---- Checking Loss values ----
# Loss: 0.17839810252189636
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 44522 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 95.86%, remaining_weights: 8.78%
#
#  ---- Checking Loss values ----
# Loss: 0.211436927318573
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 44719 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 97.11%, remaining_weights: 8.77%
#
#  ---- Checking Loss values ----
# Loss: 0.1761568784713745
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 44916 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 95.76%, remaining_weights: 8.69%
#
#  ---- Checking Loss values ----
# Loss: 0.21442539989948273
# Model Losses: 0.0
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 45113 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 0.0
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 97.44%, remaining_weights: 8.67%

# %%
#print layers and lmbda weights in the model

for name, layer in model.named_modules():
    if hasattr(layer, "lmbda"):
        print(f"Layer: {name}, lmbda: {layer.lmbda}")
# Out:
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm/equality_constraint/equality_constraint_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer1.0.conv1.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_1/equality_constraint_1/equality_constraint_1_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer1.0.conv2.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_2/equality_constraint_2/equality_constraint_2_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer1.1.conv1.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_3/equality_constraint_3/equality_constraint_3_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer1.1.conv2.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_4/equality_constraint_4/equality_constraint_4_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer2.0.conv1.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_5/equality_constraint_5/equality_constraint_5_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer2.0.conv2.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_6/equality_constraint_6/equality_constraint_6_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer2.0.downsample.0.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_7/equality_constraint_7/equality_constraint_7_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer2.1.conv1.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_8/equality_constraint_8/equality_constraint_8_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer2.1.conv2.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_9/equality_constraint_9/equality_constraint_9_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer3.0.conv1.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_10/equality_constraint_10/equality_constraint_10_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer3.0.conv2.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_11/equality_constraint_11/equality_constraint_11_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer3.0.downsample.0.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_12/equality_constraint_12/equality_constraint_12_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer3.1.conv1.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_13/equality_constraint_13/equality_constraint_13_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer3.1.conv2.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_14/equality_constraint_14/equality_constraint_14_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer4.0.conv1.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_15/equality_constraint_15/equality_constraint_15_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer4.0.conv2.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_16/equality_constraint_16/equality_constraint_16_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer4.0.downsample.0.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_17/equality_constraint_17/equality_constraint_17_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer4.1.conv1.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_18/equality_constraint_18/equality_constraint_18_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: layer4.1.conv2.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_19/equality_constraint_19/equality_constraint_19_lmbda, shape=(), dtype=float32, value=0.0>
# Layer: fc.pruning_layer.constraint_layer.module, lmbda: <Variable path=mdmm_20/equality_constraint_20/equality_constraint_20_lmbda, shape=(), dtype=float32, value=0.0>

# %%
import numpy as np
from pquant import remove_pruning_from_model
import matplotlib.pyplot as plt
# Remove compression layers, leaves Quantized activations in place
model = remove_pruning_from_model(trained_model, config)

# Plot remaining weights
names = []
remaining = []
total_w = []
nonzeros = []
for n, m in model.named_modules():
    if isinstance(m, (torch.nn.Conv1d, torch.nn.Conv2d, torch.nn.Linear)):
        names.append(n)
        # nonzero = np.count_nonzero(m.weight.detach().cpu())
        nonzero = torch.sum(torch.abs(m.weight.detach().cpu()) > 1e-3).item()
        remaining_pct = nonzero / m.weight.numel()
        remaining.append(remaining_pct)
        total_w.append(m.weight.numel())
        nonzeros.append(nonzero)
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].bar(range(len(names)), remaining)
ax[0].set_xticks(range(len(names)))
ax[0].set_xticklabels(names)
ax[0].tick_params(axis='x', labelrotation=270)
new_ytick = []
for i in ax[0].get_yticklabels():
    ytick = f"{float(i.get_text()) * 100}%"
    new_ytick.append(ytick)
ax[0].set_yticklabels(new_ytick)
ax[0].title.set_text("Remaining weights per layer")

ax[1].bar(range(len(nonzeros)), total_w, color="lightcoral", label="total weights")
ax[1].bar(range(len(nonzeros)), nonzeros, color="steelblue", label="nonzero weights")
ax[1].set_xticks(range(len(names)))
ax[1].set_xticklabels(names)
ax[1].tick_params(axis='x', labelrotation=270)
ax[1].title.set_text("Weights per layer")
ax[1].legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_860455/3926938098.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_yticklabels(new_ytick)

# %% [markdown]
# We see from that with PDP, the number of weights goes down during training, until it reaches the target sparsity (sparsity of 80%, or ~20% remaining weights). The function that calculates the remaining weights feeds the weights through the quantizer and pruning method, and calculates the ratio between non-zero weights and all weights. However, since PDP uses a soft mask during training, the percentage of remaining weights seems to go down rather noisily (can even drop from 80% to ~20% remaining weights). The algorithm actually increases the sparsity linearly.
# During fine-tuning the mask is fixed, and turned into a mask of 0s and 1s by a simple rounding operation, so the remaining weights stay the same during each epoch.
#
# In the original paper for PDP there was no fine-tuning after the creation of the final hard mask. We have added fine-tuning here as an option that can be turned off by simply setting ```fine_tuning_epochs``` to 0 in the config file.

# %%
import numpy as np
from pquant import remove_pruning_from_model
import matplotlib.pyplot as plt
# Remove compression layers, leaves Quantized activations in place
model = remove_pruning_from_model(trained_model, config)

# Plot remaining weights
names = []
remaining = []
total_w = []
nonzeros = []
for n, m in trained_model.named_modules():
    if isinstance(m, (torch.nn.Conv1d, torch.nn.Conv2d, torch.nn.Linear)):
        names.append(n)
        nonzero = np.count_nonzero(m.weight.detach().cpu())
        remaining_pct = nonzero / m.weight.numel()
        remaining.append(remaining_pct)
        total_w.append(m.weight.numel())
        nonzeros.append(nonzero)
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].bar(range(len(names)), remaining)
ax[0].set_xticks(range(len(names)))
ax[0].set_xticklabels(names)
ax[0].tick_params(axis='x', labelrotation=270)
new_ytick = []
for i in ax[0].get_yticklabels():
    ytick = f"{float(i.get_text()) * 100}%"
    new_ytick.append(ytick)
ax[0].set_yticklabels(new_ytick)
ax[0].title.set_text("Remaining weights per layer")

ax[1].bar(range(len(nonzeros)), total_w, color="lightcoral", label="total weights")
ax[1].bar(range(len(nonzeros)), nonzeros, color="steelblue", label="nonzero weights")
ax[1].set_xticks(range(len(names)))
ax[1].set_xticklabels(names)
ax[1].tick_params(axis='x', labelrotation=270)
ax[1].title.set_text("Weights per layer")
ax[1].legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_860455/4147432696.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_yticklabels(new_ytick)

# %% [markdown]
# ## Custom config from existing config
# Using the ```pquant/configs/config_pdp.yaml``` as base, let's customize the quantization and pruning scheme.
#
# The function we use will go through the model's layers and do the following:
#
# Quantization:
#
#         1. Looks for the names of convolutional and linear layers, as well as names of the activations (layer type activations and functional types)
#         2. Adds the name of the layer to the layer_specific list, along with a default quantization scheme of 0 and 7 for weight and bias (if bias is not None)
#
# Pruning:
#
#         1. Looks for convolutional and linear layers and adds their name to the disable_pruning_for_layers list.

# %%
# Base config
pruning_method = "pdp"
config = get_default_config(pruning_method)
model = torchvision.models.resnet18()


from pquant import add_default_layer_quantization_pruning_to_config
config = add_default_layer_quantization_pruning_to_config(model, config)
config
# Out:
# /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,
# {'pruning_parameters': {'disable_pruning_for_layers': ['conv1',
#    'layer1.0.conv1',
#    'layer1.0.conv2',
#    'layer1.1.conv1',
#    'layer1.1.conv2',
#    'layer2.0.conv1',
#    'layer2.0.conv2',
#    'layer2.0.downsample.0',
#    'layer2.1.conv1',
#    'layer2.1.conv2',
#    'layer3.0.conv1',
#    'layer3.0.conv2',
#    'layer3.0.downsample.0',
#    'layer3.1.conv1',
#    'layer3.1.conv2',
#    'layer4.0.conv1',
#    'layer4.0.conv2',
#    'layer4.0.downsample.0',
#    'layer4.1.conv1',
#    'layer4.1.conv2',
#    'fc'],
#   'enable_pruning': True,
#   'epsilon': 0.015,
#   'pruning_method': 'pdp',
#   'sparsity': 0.8,
#   'temperature': 1e-05,
#   'threshold_decay': 0.0,
#   'structured_pruning': False},
#  'quantization_parameters': {'default_integer_bits': 0.0,
#   'default_fractional_bits': 7.0,
#   'enable_quantization': True,
#   'hgq_gamma': 0.0003,
#   'hgq_heterogeneous': True,
#   'layer_specific': {'conv1': {'weight': {'integer_bits': 0,
#      'fractional_bits': 7}},
#    'relu': {'integer_bits': 0, 'fractional_bits': 7},
#    'layer1.0.conv1': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer1.0.relu': {'integer_bits': 0, 'fractional_bits': 7},
#    'layer1.0.conv2': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer1.1.conv1': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer1.1.relu': {'integer_bits': 0, 'fractional_bits': 7},
#    'layer1.1.conv2': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer2.0.conv1': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer2.0.relu': {'integer_bits': 0, 'fractional_bits': 7},
#    'layer2.0.conv2': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer2.0.downsample.0': {'weight': {'integer_bits': 0,
#      'fractional_bits': 7}},
#    'layer2.1.conv1': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer2.1.relu': {'integer_bits': 0, 'fractional_bits': 7},
#    'layer2.1.conv2': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer3.0.conv1': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer3.0.relu': {'integer_bits': 0, 'fractional_bits': 7},
#    'layer3.0.conv2': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer3.0.downsample.0': {'weight': {'integer_bits': 0,
#      'fractional_bits': 7}},
#    'layer3.1.conv1': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer3.1.relu': {'integer_bits': 0, 'fractional_bits': 7},
#    'layer3.1.conv2': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer4.0.conv1': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer4.0.relu': {'integer_bits': 0, 'fractional_bits': 7},
#    'layer4.0.conv2': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer4.0.downsample.0': {'weight': {'integer_bits': 0,
#      'fractional_bits': 7}},
#    'layer4.1.conv1': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'layer4.1.relu': {'integer_bits': 0, 'fractional_bits': 7},
#    'layer4.1.conv2': {'weight': {'integer_bits': 0, 'fractional_bits': 7}},
#    'fc': {'weight': {'integer_bits': 0, 'fractional_bits': 7},
#     'bias': {'integer_bits': 0, 'fractional_bits': 7}}},
#   'use_high_granularity_quantization': False,
#   'use_real_tanh': False,
#   'use_symmetric_quantization': False},
#  'training_parameters': {'epochs': 100,
#   'fine_tuning_epochs': 20,
#   'pretraining_epochs': 20,
#   'pruning_first': False,
#   'rewind': 'never',
#   'rounds': 1,
#   'save_weights_epoch': -1},
#  'batch_size': 256,
#  'cosine_tmax': 200,
#  'gamma': 0.1,
#  'l2_decay': 0.0001,
#  'label_smoothing': 0.0,
#  'lr': 0.01,
#  'lr_schedule': 'cosine',
#  'milestones': [-1, -1],
#  'momentum': 0.9,
#  'optimizer': 'sgd',
#  'plot_frequency': 100}

# %%
# Save config
from pquant.core.utils import write_config_to_yaml
write_config_to_yaml(config, "prune_quantize_example.yaml", sort_keys=False)

# %% [markdown]
# Now that we have the custom config, it is up to us to modify the quantization bits for each layer that will not use the default value. If a layer uses the default value it can be removed from the ```layer_specific``` list.
#
# For pruning, leave those layers to the ```disable_pruning_for_layers``` list that will not be pruned, others need to be removed from the list.

# %% [markdown]
# ## About replacing layers and activations
# Layers that can currently be compressed: ```nn.Conv1d, nn.Conv2d, nn.Linear```.
#
# Activations that can currently be automatically be replaced with a quantized variant: ```nn.ReLU, nn.Tanh```. The activations are replaced by a quantized variant, found in ```pquant.core.activations_quantizer.py```.

# %% [markdown]
# ## More about activations
# If using layer type activations, note that if you want to keep the fine-grained control over the quantization of the activation, reusing an activation layer can cause problems, as all activations will use the quantization bits set for that particular layer. To avoid this, use a separate ```nn.Tanh``` / ```nn.ReLU``` for each activation

# %% [markdown]
# ## HGQ
# To use HGQ, enable it in the config: `config["quantization_parameters"]["use_high_granularity_quantization"] = True`. Other relevant parameters to tune are `config["quantization_parameters"]["default_integer_bits"]`, `config["quantization_parameters"]["default_fractional_bits"]`, `config["quantization_parameters"]["hgq_gamma"]`.
# When using HGQ, we advice using Adam instead of SGD as an optimizer.
