# %% [markdown]
# ## In this tutorial we create a CNN and dataloaders, and train / prune the model.

# %%
import os
os.environ["KERAS_BACKEND"] = "torch" # Needs to be set, some pruning layers as well as the quantizers are Keras
import keras
keras.config.set_backend("torch")
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
keras.backend.set_image_data_format("channels_first")
# Out:
# /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
os.chdir("/home/das214/PQuant/MDMM/src")

# %%
model = torchvision.models.resnet18()
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
model = model.to(device)

model
# Out:
# Using device: cuda
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# ## Add pruning and quantization
# To add pruning and quantization, we need a config file that defines how to do that. Let's load a config file from pquant/configs/configs_pdp.yaml. The training function we use later will add the pruning layers and quantized activations automatically using this config

# %%
from pquant import get_default_config

# pruning_methods: "autosparse, cl, cs, dst, pdp, wanda"
pruning_method = "mdmm"
config = get_default_config(pruning_method)
# Set target sparsity to 80% (20% of weights are non-zero). This parameter exists only for some pruning methods
config["pruning_parameters"]["sparsity"] = 0.8
# Check what's inside the config
config
# Out:
# {'pruning_parameters': {'pruning_method': 'mdmm',
#   'enable_pruning': True,
#   'disable_pruning_for_layers': [None],
#   'constraint_type': 'Equality',
#   'target_value': 0.0,
#   'metric_type': 'UnstructuredSparsity',
#   'target_sparsity': 0.9,
#   'rf': 1,
#   'epsilon': 0.001,
#   'scale': 10.0,
#   'damping': 1.0,
#   'use_grad': False,
#   'l0_mode': 'coarse',
#   'sparsity': 0.8},
#  'quantization_parameters': {'enable_quantization': False,
#   'default_integer_bits': 0.0,
#   'default_fractional_bits': 7.0,
#   'hgq_gamma': 0.0003,
#   'hgq_heterogeneous': True,
#   'layer_specific': [],
#   'use_high_granularity_quantization': False,
#   'use_real_tanh': False,
#   'use_symmetric_quantization': False},
#  'training_parameters': {'epochs': 300,
#   'fine_tuning_epochs': 0,
#   'pretraining_epochs': 0,
#   'pruning_first': False,
#   'rewind': 'never',
#   'rounds': 1,
#   'save_weights_epoch': -1},
#  'batch_size': 128,
#  'cosine_tmax': 200,
#  'gamma': 0.1,
#  'l2_decay': 0.0001,
#  'label_smoothing': 0.0,
#  'lr': 0.01,
#  'lr_schedule': 'multistep',
#  'milestones': [75, 120],
#  'momentum': 0.9,
#  'optimizer': 'sgd',
#  'plot_frequency': 100}

# %%
# Replace layers with compressed layers
from pquant import add_compression_layers
input_shape = (256,3,32,32)
model = add_compression_layers(model, config, input_shape)
model
# Out:
# ResNet(
#   (conv1): CompressedLayerConv2d(
#     (pruning_layer): <MDMM name=mdmm, built=True>
#   )
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_1, built=True>
#       )
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_2, built=True>
#       )
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_3, built=True>
#       )
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_4, built=True>
#       )
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_5, built=True>
#       )
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_6, built=True>
#       )
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): CompressedLayerConv2d(
#           (pruning_layer): <MDMM name=mdmm_7, built=True>
#         )
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_8, built=True>
#       )
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_9, built=True>
#       )
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_10, built=True>
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_11, built=True>
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): CompressedLayerConv2d(
#           (pruning_layer): <MDMM name=mdmm_12, built=True>
#         )
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_13, built=True>
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_14, built=True>
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_15, built=True>
#       )
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_16, built=True>
#       )
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): CompressedLayerConv2d(
#           (pruning_layer): <MDMM name=mdmm_17, built=True>
#         )
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_18, built=True>
#       )
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_19, built=True>
#       )
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): CompressedLayerLinear(
#     (pruning_layer): <MDMM name=mdmm_20, built=True>
#   )
# )

# %% [markdown]
# ## Pruning and quantization in the config
# From the config we see that we are using the PDP pruning method, unstructured version. We aim for 80% weights pruned (sparsity 0.8), and we quantize the model to 8 bits (1 bit goes to sign).
# By default, all convolutional and linear layers, as well as activations will be quantized using the default values ```default_integer_bits``` and ```default_fractional_bits```. Similarly, by default all convolutional and linear layers will be pruned.
#
# We can disable pruning and/or quantization by setting the enable_pruning / enable_quantization to False. To change quantization bits for a specific layer, add the layers name to the list found in ```layer_specific```, followed by number of bits. To disable pruning for a single layer, add its name to the ```disable_pruning_for_layers``` list.
#
# We'll show later how to create a custom quantization / pruning config file from an existing config for a given model

# %% [markdown]
# ## About the different epochs
#
# The config defines 20 ```pretraining_epochs```, 100 ```epochs``` and 20 ```fine_tuning_epochs```. What happens during each of these training steps is algorithm specific.
#
# In PDP, the pretraining phase consists of training without pruning, followed by calculation of layerwise pruning budgets. After pretraining is finished and the layerwise pruning budgets have been calculated, the training with pruning begins. The mask during this training is a soft mask, consisting of values ranging between (and including) 0 and 1.
#
# The fine-tuning step in PDP is optional (not mentioned in the original paper), and during it the mask is fixed and rounded to 0s and 1s.

# %% [markdown]
# ## Create data set
# #### Let's create the data loader and the training and validation loops

# %%
import torchvision.transforms as transforms

def get_cifar10_data(batch_size):
    normalize = transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    train_transform = transforms.Compose([transforms.RandomHorizontalFlip(), transforms.RandomCrop(32, padding=4), 
                                          transforms.ToTensor(), normalize])
    test_transform = transforms.Compose([transforms.ToTensor(), normalize])  
    trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=train_transform)
    valset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                       download=True, transform=test_transform)
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=4, pin_memory=True)

    val_loader = torch.utils.data.DataLoader(valset, batch_size=batch_size,
                                         shuffle=False, num_workers=4, pin_memory=True)

    return train_loader, val_loader

from quantizers.fixed_point.fixed_point_ops import get_fixed_quantizer
# Set up input quantizer
quantizer = get_fixed_quantizer(overflow_mode="SAT")


def train_resnet(model, trainloader, device, loss_func, epoch, optimizer, scheduler, *args, **kwargs):
    first_batch = True
    for data in trainloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        inputs = quantizer(inputs, k=torch.tensor(1.), i=torch.tensor(0.), f=torch.tensor(7.)) # 8 bits input quantization
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_func(outputs, labels)
        losses = get_model_losses(model, torch.tensor(0.).to(device))
        loss += losses
        loss.backward()
        
        if first_batch:
            print("\n ---- Checking Loss values ----")
            print("Loss:", loss_func(outputs, labels).item())
            print("Model Losses:", losses.item())
            print("--------------------------------------------------")
            print(f"\n--- Checking Gradients for lmbda at Epoch {epoch} ---")
            for name, module in model.named_modules():
                if "pruning_layer.constraint_layer.module" in name and hasattr(module, "lmbda"):
                    # Access the underlying tensor via the '.value' attribute
                    underlying_tensor = module.lmbda.value
                    grad_value = underlying_tensor.grad
                    print(f"Layer: {name}, lmbda: {underlying_tensor.item()}")
                    if grad_value is not None:
                        print(f"Layer: {name}, Gradient: {grad_value.item()}")
                    else:
                        print(f"Layer: {name}, Gradient: None")
                        
                    break
            print("--------------------------------------------------\n")
            first_batch = False
            
        optimizer.step()
        epoch += 1
        if scheduler is not None:
            scheduler.step()


from pquant import get_layer_keep_ratio, get_model_losses

def validate_resnet(model, testloader, device, loss_func, epoch, *args, **kwargs):
    correct = 0
    total = 0
    model.eval()
    with torch.no_grad():
        for data in testloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            inputs = quantizer(inputs, k=torch.tensor(1.), i=torch.tensor(0.), f=torch.tensor(7.)) # 8 bits input quantization
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        ratio = get_layer_keep_ratio(model)
        print(f'Accuracy: {100 * correct / total:.2f}%, remaining_weights: {ratio * 100:.2f}%')

BATCH_SIZE = 256
train_loader, val_loader = get_cifar10_data(BATCH_SIZE)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Create loss function, scheduler and optimizer

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR

optimizer = torch.optim.SGD(model.parameters(), lr=0.01, weight_decay=0.0001, momentum=0.9)
scheduler = CosineAnnealingLR(optimizer, 200)
loss_function = nn.CrossEntropyLoss()

# %% [markdown]
# ## Train model
# Training time. We use the train_compressed_model function from pquant to train. We need to provide some parameters such as training and validation functions, their input parameters, the model and the config file. The function automatically adds pruning layers and replaces activations with a quantized variant, trains the model, and removes the pruning layers after training is done

# %%
from pquant import iterative_train
"""
Inputs to train_resnet we defined previously are:
          model, trainloader, device, loss_func, epoch, optimizer, scheduler, **kwargs
"""

trained_model = iterative_train(model = model, 
                                config = config, 
                                train_func = train_resnet, 
                                valid_func = validate_resnet, 
                                trainloader = train_loader, 
                                testloader = val_loader, 
                                device = device, 
                                loss_func = loss_function,
                                optimizer = optimizer, 
                                scheduler = scheduler
                                )
# Out:
#  ---- Checking Loss values ----
# Loss: 7.319949626922607
# Model Losses: 6.156798839569092
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 0 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 1.001628041267395
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 48.10%, remaining_weights: 96.32%
#
#  ---- Checking Loss values ----
# Loss: 1.3669813871383667
# Model Losses: 13.884577751159668
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 197 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 1.6716735363006592
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 47.30%, remaining_weights: 95.80%
#
#  ---- Checking Loss values ----
# Loss: 1.4856362342834473
# Model Losses: 17.693950653076172
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 394 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.1478240489959717
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 59.00%, remaining_weights: 94.89%
#
#  ---- Checking Loss values ----
# Loss: 1.1537097692489624
# Model Losses: 17.899734497070312
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 591 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.409968614578247
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 47.66%, remaining_weights: 94.20%
#
#  ---- Checking Loss values ----
# Loss: 1.3451778888702393
# Model Losses: 18.786819458007812
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 788 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.6660850048065186
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.44%, remaining_weights: 92.74%
#
#  ---- Checking Loss values ----
# Loss: 1.0925066471099854
# Model Losses: 16.638883590698242
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 985 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.8799941539764404
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 49.12%, remaining_weights: 92.09%
#
#  ---- Checking Loss values ----
# Loss: 1.2750719785690308
# Model Losses: 17.23301887512207
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1182 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.1063060760498047
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.13%, remaining_weights: 90.14%
#
#  ---- Checking Loss values ----
# Loss: 1.0780411958694458
# Model Losses: 14.699809074401855
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1379 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.2901599407196045
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 52.19%, remaining_weights: 89.58%
#
#  ---- Checking Loss values ----
# Loss: 1.2983641624450684
# Model Losses: 15.514175415039062
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1576 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.4858992099761963
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.71%, remaining_weights: 87.34%
#
#  ---- Checking Loss values ----
# Loss: 1.0385771989822388
# Model Losses: 13.127584457397461
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1773 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.6514718532562256
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 42.93%, remaining_weights: 86.89%
#
#  ---- Checking Loss values ----
# Loss: 1.1902326345443726
# Model Losses: 13.889738082885742
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1970 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.8224542140960693
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.02%, remaining_weights: 84.43%
#
#  ---- Checking Loss values ----
# Loss: 0.9164815545082092
# Model Losses: 11.824437141418457
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2167 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.9714818000793457
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 52.34%, remaining_weights: 84.05%
#
#  ---- Checking Loss values ----
# Loss: 1.2287122011184692
# Model Losses: 12.501864433288574
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2364 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.129411697387695
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.04%, remaining_weights: 81.44%
#
#  ---- Checking Loss values ----
# Loss: 1.065592885017395
# Model Losses: 10.741185188293457
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2561 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.270962238311768
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 51.76%, remaining_weights: 81.10%
#
#  ---- Checking Loss values ----
# Loss: 1.17440664768219
# Model Losses: 11.301473617553711
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2758 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.406494617462158
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.58%, remaining_weights: 78.37%
#
#  ---- Checking Loss values ----
# Loss: 0.9400443434715271
# Model Losses: 9.819009780883789
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2955 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.537322998046875
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 48.50%, remaining_weights: 77.97%
#
#  ---- Checking Loss values ----
# Loss: 1.276026964187622
# Model Losses: 10.228832244873047
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3152 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.657029151916504
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.17%, remaining_weights: 75.40%
#
#  ---- Checking Loss values ----
# Loss: 1.034607172012329
# Model Losses: 9.06867504119873
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3349 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.783576011657715
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 46.29%, remaining_weights: 74.88%
#
#  ---- Checking Loss values ----
# Loss: 1.2459779977798462
# Model Losses: 9.315376281738281
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3546 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.895604610443115
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.89%, remaining_weights: 72.37%
#
#  ---- Checking Loss values ----
# Loss: 1.0445775985717773
# Model Losses: 8.337583541870117
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3743 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.017370700836182
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 55.10%, remaining_weights: 71.77%
#
#  ---- Checking Loss values ----
# Loss: 1.2876416444778442
# Model Losses: 8.495787620544434
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3940 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.12202262878418
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.32%, remaining_weights: 69.42%
#
#  ---- Checking Loss values ----
# Loss: 0.9909496307373047
# Model Losses: 7.708568572998047
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4137 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.239100933074951
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 58.92%, remaining_weights: 68.49%
#
#  ---- Checking Loss values ----
# Loss: 1.0031867027282715
# Model Losses: 7.611429214477539
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4334 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.328860759735107
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.62%, remaining_weights: 66.47%
#
#  ---- Checking Loss values ----
# Loss: 0.918298602104187
# Model Losses: 7.086971282958984
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4531 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.441952705383301
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.24%, remaining_weights: 65.37%
#
#  ---- Checking Loss values ----
# Loss: 1.0340825319290161
# Model Losses: 6.869626522064209
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4728 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.525005340576172
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 60.09%, remaining_weights: 63.64%
#
#  ---- Checking Loss values ----
# Loss: 0.9338445067405701
# Model Losses: 6.577390670776367
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4925 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.6443586349487305
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 57.39%, remaining_weights: 62.31%
#
#  ---- Checking Loss values ----
# Loss: 1.0831857919692993
# Model Losses: 6.214756488800049
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5122 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.722358703613281
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 61.63%, remaining_weights: 60.91%
#
#  ---- Checking Loss values ----
# Loss: 1.107507586479187
# Model Losses: 6.083910942077637
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5319 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.833909034729004
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 61.63%, remaining_weights: 59.39%
#
#  ---- Checking Loss values ----
# Loss: 0.8286614418029785
# Model Losses: 5.6071391105651855
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5516 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.902109622955322
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.32%, remaining_weights: 58.40%
#
#  ---- Checking Loss values ----
# Loss: 0.9946027994155884
# Model Losses: 5.719728469848633
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5713 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.018430709838867
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 72.03%, remaining_weights: 56.65%
#
#  ---- Checking Loss values ----
# Loss: 0.8190809488296509
# Model Losses: 5.084434509277344
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5910 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.077239990234375
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.98%, remaining_weights: 55.82%
#
#  ---- Checking Loss values ----
# Loss: 1.009061336517334
# Model Losses: 5.267936706542969
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6107 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.188964366912842
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 71.45%, remaining_weights: 54.05%
#
#  ---- Checking Loss values ----
# Loss: 0.7370051145553589
# Model Losses: 4.630895137786865
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6304 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.248226642608643
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.37%, remaining_weights: 53.52%
#
#  ---- Checking Loss values ----
# Loss: 1.1820309162139893
# Model Losses: 4.9379401206970215
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6501 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.359517574310303
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 74.45%, remaining_weights: 51.62%
#
#  ---- Checking Loss values ----
# Loss: 0.664766788482666
# Model Losses: 4.2366461753845215
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6698 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.412911891937256
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.07%, remaining_weights: 51.12%
#
#  ---- Checking Loss values ----
# Loss: 0.9709008932113647
# Model Losses: 4.5589118003845215
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6895 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.518576145172119
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 74.48%, remaining_weights: 49.22%
#
#  ---- Checking Loss values ----
# Loss: 0.8011838793754578
# Model Losses: 3.864593744277954
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7092 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.569079399108887
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 55.40%, remaining_weights: 49.05%
#
#  ---- Checking Loss values ----
# Loss: 1.1865906715393066
# Model Losses: 4.330724716186523
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7289 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.676890850067139
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 76.81%, remaining_weights: 46.99%
#
#  ---- Checking Loss values ----
# Loss: 0.7473963499069214
# Model Losses: 3.533322334289551
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7486 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.725104808807373
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.23%, remaining_weights: 46.98%
#
#  ---- Checking Loss values ----
# Loss: 1.003546953201294
# Model Losses: 4.019428253173828
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7683 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.827587127685547
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.55%, remaining_weights: 44.93%
#
#  ---- Checking Loss values ----
# Loss: 0.6993993520736694
# Model Losses: 3.261187791824341
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7880 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.876367092132568
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.18%, remaining_weights: 44.96%
#
#  ---- Checking Loss values ----
# Loss: 1.0603855848312378
# Model Losses: 3.7293922901153564
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8077 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.973225116729736
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.95%, remaining_weights: 42.97%
#
#  ---- Checking Loss values ----
# Loss: 0.7100483775138855
# Model Losses: 2.995436429977417
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8274 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.022186756134033
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.97%, remaining_weights: 43.18%
#
#  ---- Checking Loss values ----
# Loss: 1.0051425695419312
# Model Losses: 3.51792573928833
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8471 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.116017818450928
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.21%, remaining_weights: 41.14%
#
#  ---- Checking Loss values ----
# Loss: 0.6283668875694275
# Model Losses: 2.7686514854431152
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8668 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.168378829956055
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 57.43%, remaining_weights: 41.30%
#
#  ---- Checking Loss values ----
# Loss: 1.064574956893921
# Model Losses: 3.221489906311035
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8865 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.257813930511475
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.28%, remaining_weights: 39.41%
#
#  ---- Checking Loss values ----
# Loss: 0.6205410361289978
# Model Losses: 2.5461487770080566
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9062 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.30918550491333
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 58.15%, remaining_weights: 39.88%
#
#  ---- Checking Loss values ----
# Loss: 1.0565835237503052
# Model Losses: 3.120532751083374
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9259 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.400693893432617
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.52%, remaining_weights: 37.83%
#
#  ---- Checking Loss values ----
# Loss: 0.7369157075881958
# Model Losses: 2.3524763584136963
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9456 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.454160213470459
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 59.05%, remaining_weights: 38.26%
#
#  ---- Checking Loss values ----
# Loss: 1.0226095914840698
# Model Losses: 2.9144558906555176
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9653 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.542723178863525
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.76%, remaining_weights: 36.26%
#
#  ---- Checking Loss values ----
# Loss: 0.7456486821174622
# Model Losses: 2.1580517292022705
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9850 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.59574556350708
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 55.98%, remaining_weights: 36.79%
#
#  ---- Checking Loss values ----
# Loss: 0.9571080803871155
# Model Losses: 2.7024641036987305
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10047 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.676730155944824
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 79.11%, remaining_weights: 34.89%
#
#  ---- Checking Loss values ----
# Loss: 0.7614452838897705
# Model Losses: 1.9965431690216064
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10244 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.72986364364624
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 60.52%, remaining_weights: 35.40%
#
#  ---- Checking Loss values ----
# Loss: 0.8931711316108704
# Model Losses: 2.5619890689849854
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10441 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.8177642822265625
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.97%, remaining_weights: 33.54%
#
#  ---- Checking Loss values ----
# Loss: 0.6429274082183838
# Model Losses: 1.8512228727340698
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10638 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.872472286224365
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 56.87%, remaining_weights: 34.01%
#
#  ---- Checking Loss values ----
# Loss: 1.157189130783081
# Model Losses: 2.34702730178833
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10835 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.949734687805176
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 79.27%, remaining_weights: 32.40%
#
#  ---- Checking Loss values ----
# Loss: 0.717307984828949
# Model Losses: 1.7296838760375977
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11032 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.005383491516113
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.70%, remaining_weights: 32.78%
#
#  ---- Checking Loss values ----
# Loss: 0.871671736240387
# Model Losses: 2.171860456466675
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11229 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.077658653259277
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.23%, remaining_weights: 31.27%
#
#  ---- Checking Loss values ----
# Loss: 0.7259172797203064
# Model Losses: 1.6208558082580566
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11426 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.134866714477539
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 54.83%, remaining_weights: 31.68%
#
#  ---- Checking Loss values ----
# Loss: 0.9884778261184692
# Model Losses: 2.100250244140625
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11623 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.20903491973877
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.66%, remaining_weights: 30.33%
#
#  ---- Checking Loss values ----
# Loss: 0.6303786635398865
# Model Losses: 1.5400371551513672
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11820 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.266237258911133
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.76%, remaining_weights: 30.51%
#
#  ---- Checking Loss values ----
# Loss: 1.0481129884719849
# Model Losses: 1.9132276773452759
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12017 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.33276081085205
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.30%, remaining_weights: 29.43%
#
#  ---- Checking Loss values ----
# Loss: 0.5522034168243408
# Model Losses: 1.4701670408248901
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12214 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.39283275604248
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 59.30%, remaining_weights: 29.55%
#
#  ---- Checking Loss values ----
# Loss: 0.9457990527153015
# Model Losses: 1.795396327972412
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12411 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.455512046813965
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.38%, remaining_weights: 28.61%
#
#  ---- Checking Loss values ----
# Loss: 0.6418160200119019
# Model Losses: 1.4041876792907715
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12608 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.516073226928711
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 69.52%, remaining_weights: 28.48%
#
#  ---- Checking Loss values ----
# Loss: 0.9092511534690857
# Model Losses: 1.6211186647415161
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12805 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.573291778564453
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 75.64%, remaining_weights: 27.84%
#
#  ---- Checking Loss values ----
# Loss: 0.7815934419631958
# Model Losses: 1.3744137287139893
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13002 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.640267372131348
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.60%, remaining_weights: 27.58%
#
#  ---- Checking Loss values ----
# Loss: 0.9933903813362122
# Model Losses: 1.530099868774414
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13199 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.700096130371094
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 76.68%, remaining_weights: 27.15%
#
#  ---- Checking Loss values ----
# Loss: 0.7507995367050171
# Model Losses: 1.317185640335083
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13396 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.764863967895508
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.20%, remaining_weights: 26.76%
#
#  ---- Checking Loss values ----
# Loss: 0.7590849995613098
# Model Losses: 1.4237697124481201
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13593 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.822423934936523
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 73.54%, remaining_weights: 26.61%
#
#  ---- Checking Loss values ----
# Loss: 0.7021887302398682
# Model Losses: 1.3048925399780273
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13790 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.88937759399414
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.02%, remaining_weights: 25.98%
#
#  ---- Checking Loss values ----
# Loss: 0.7385055422782898
# Model Losses: 1.26051664352417
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13987 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.937816619873047
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 74.34%, remaining_weights: 26.03%
#
#  ---- Checking Loss values ----
# Loss: 0.7739665508270264
# Model Losses: 1.2730242013931274
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14184 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.00580883026123
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 72.00%, remaining_weights: 25.25%
#
#  ---- Checking Loss values ----
# Loss: 0.8007956147193909
# Model Losses: 1.1376513242721558
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14381 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.049521446228027
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 72.52%, remaining_weights: 25.55%
#
#  ---- Checking Loss values ----
# Loss: 0.6448436975479126
# Model Losses: 1.3022233247756958
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14578 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.120405197143555
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 75.86%, remaining_weights: 24.63%
#
#  ---- Checking Loss values ----
# Loss: 0.7327255010604858
# Model Losses: 1.0509744882583618
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14775 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.160122871398926
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 72.34%, remaining_weights: 25.12%
#
#  ---- Checking Loss values ----
# Loss: 0.8170012831687927
# Model Losses: 1.2927844524383545
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14972 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.230607032775879
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 75.46%, remaining_weights: 24.08%
#
#  ---- Checking Loss values ----
# Loss: 0.6014315485954285
# Model Losses: 0.9717782735824585
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15169 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.267537117004395
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 68.05%, remaining_weights: 24.58%
#
#  ---- Checking Loss values ----
# Loss: 0.7406686544418335
# Model Losses: 1.2500396966934204
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15366 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.336457252502441
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 79.57%, remaining_weights: 23.51%
#
#  ---- Checking Loss values ----
# Loss: 0.6349546313285828
# Model Losses: 0.8889521956443787
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15563 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.368355751037598
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.01%, remaining_weights: 24.20%
#
#  ---- Checking Loss values ----
# Loss: 0.8749575614929199
# Model Losses: 1.2464593648910522
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15760 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.4363374710083
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 79.95%, remaining_weights: 23.13%
#
#  ---- Checking Loss values ----
# Loss: 0.7335283756256104
# Model Losses: 0.860929548740387
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15957 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.468498229980469
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 69.58%, remaining_weights: 23.85%
#
#  ---- Checking Loss values ----
# Loss: 0.8303890824317932
# Model Losses: 1.2569388151168823
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16154 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.536946296691895
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 80.69%, remaining_weights: 22.72%
#
#  ---- Checking Loss values ----
# Loss: 0.5408706665039062
# Model Losses: 0.8176321983337402
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16351 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.566723823547363
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.47%, remaining_weights: 23.50%
#
#  ---- Checking Loss values ----
# Loss: 0.8094731569290161
# Model Losses: 1.2705637216567993
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16548 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.636138916015625
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 80.65%, remaining_weights: 22.38%
#
#  ---- Checking Loss values ----
# Loss: 0.5623052716255188
# Model Losses: 0.7992030382156372
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16745 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.666479110717773
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 68.44%, remaining_weights: 23.19%
#
#  ---- Checking Loss values ----
# Loss: 0.7755348682403564
# Model Losses: 1.2948267459869385
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16942 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.737703323364258
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 81.84%, remaining_weights: 22.01%
#
#  ---- Checking Loss values ----
# Loss: 0.5524569749832153
# Model Losses: 0.772521436214447
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17139 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.76817512512207
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.32%, remaining_weights: 22.78%
#
#  ---- Checking Loss values ----
# Loss: 0.803410530090332
# Model Losses: 1.2507537603378296
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17336 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.835315704345703
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.15%, remaining_weights: 21.68%
#
#  ---- Checking Loss values ----
# Loss: 0.5047303438186646
# Model Losses: 0.7593909502029419
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17533 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.866231918334961
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 70.65%, remaining_weights: 22.55%
#
#  ---- Checking Loss values ----
# Loss: 0.9910548329353333
# Model Losses: 1.2803806066513062
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17730 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.93087100982666
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.52%, remaining_weights: 21.31%
#
#  ---- Checking Loss values ----
# Loss: 0.5267658233642578
# Model Losses: 0.7434592247009277
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17927 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.962848663330078
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.17%, remaining_weights: 22.26%
#
#  ---- Checking Loss values ----
# Loss: 0.8852307796478271
# Model Losses: 1.2787232398986816
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18124 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.028899192810059
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.56%, remaining_weights: 21.05%
#
#  ---- Checking Loss values ----
# Loss: 0.5523569583892822
# Model Losses: 0.7377500534057617
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18321 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.061854362487793
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.76%, remaining_weights: 21.94%
#
#  ---- Checking Loss values ----
# Loss: 0.8742966651916504
# Model Losses: 1.2751797437667847
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18518 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.129000663757324
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.89%, remaining_weights: 20.85%
#
#  ---- Checking Loss values ----
# Loss: 0.5234844088554382
# Model Losses: 0.7408507466316223
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18715 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.164031028747559
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.87%, remaining_weights: 21.76%
#
#  ---- Checking Loss values ----
# Loss: 0.810906171798706
# Model Losses: 1.28302001953125
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18912 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.228293418884277
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.71%, remaining_weights: 20.51%
#
#  ---- Checking Loss values ----
# Loss: 0.5123408436775208
# Model Losses: 0.7138410806655884
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19109 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.26401138305664
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 70.41%, remaining_weights: 21.41%
#
#  ---- Checking Loss values ----
# Loss: 0.714931309223175
# Model Losses: 1.2448891401290894
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19306 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.323989868164062
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.80%, remaining_weights: 20.26%
#
#  ---- Checking Loss values ----
# Loss: 0.571358859539032
# Model Losses: 0.7032585740089417
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19503 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.360925674438477
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.42%, remaining_weights: 21.09%
#
#  ---- Checking Loss values ----
# Loss: 0.7963773012161255
# Model Losses: 1.2786580324172974
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19700 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.428255081176758
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.97%, remaining_weights: 19.99%
#
#  ---- Checking Loss values ----
# Loss: 0.5813299417495728
# Model Losses: 0.6874268651008606
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19897 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.465578079223633
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.91%, remaining_weights: 20.76%
#
#  ---- Checking Loss values ----
# Loss: 0.7916378378868103
# Model Losses: 1.2076760530471802
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20094 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.52622127532959
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.97%, remaining_weights: 19.79%
#
#  ---- Checking Loss values ----
# Loss: 0.6118372082710266
# Model Losses: 0.6771177649497986
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20291 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.565667152404785
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.02%, remaining_weights: 20.42%
#
#  ---- Checking Loss values ----
# Loss: 0.9480279088020325
# Model Losses: 1.137658715248108
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20488 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.623637199401855
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.87%, remaining_weights: 19.61%
#
#  ---- Checking Loss values ----
# Loss: 0.5685340762138367
# Model Losses: 0.6710829138755798
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20685 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.662178039550781
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.01%, remaining_weights: 20.25%
#
#  ---- Checking Loss values ----
# Loss: 0.9041463732719421
# Model Losses: 1.1232898235321045
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20882 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.714905738830566
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 83.18%, remaining_weights: 19.41%
#
#  ---- Checking Loss values ----
# Loss: 0.6709791421890259
# Model Losses: 0.6667203903198242
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 21079 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.754487037658691
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 68.77%, remaining_weights: 19.84%
#
#  ---- Checking Loss values ----
# Loss: 0.7640187740325928
# Model Losses: 1.0299615859985352
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 21276 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.803508758544922
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.89%, remaining_weights: 19.20%
#
#  ---- Checking Loss values ----
# Loss: 0.6647207736968994
# Model Losses: 0.6693210005760193
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 21473 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.8444185256958
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.40%, remaining_weights: 19.60%
#
#  ---- Checking Loss values ----
# Loss: 0.7650291919708252
# Model Losses: 1.0411343574523926
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 21670 ---
# ...
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 39991 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.368568420410156
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 72.97%, remaining_weights: 15.60%
#
#  ---- Checking Loss values ----
# Loss: 0.509154736995697
# Model Losses: 0.8580732941627502
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 40188 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.404047012329102
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 90.02%, remaining_weights: 15.10%
#
#  ---- Checking Loss values ----
# Loss: 0.42454153299331665
# Model Losses: 0.5440271496772766
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 40385 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.432915687561035
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 75.95%, remaining_weights: 15.49%
#
#  ---- Checking Loss values ----
# Loss: 0.6477665305137634
# Model Losses: 0.8344613313674927
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 40582 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.467294692993164
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 89.65%, remaining_weights: 15.10%
#
#  ---- Checking Loss values ----
# Loss: 0.3923414647579193
# Model Losses: 0.5546426177024841
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 40779 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.498409271240234
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.55%, remaining_weights: 15.39%
#
#  ---- Checking Loss values ----
# Loss: 0.5791098475456238
# Model Losses: 0.7942392826080322
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 40976 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.531240463256836
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 88.94%, remaining_weights: 15.07%
#
#  ---- Checking Loss values ----
# Loss: 0.34801802039146423
# Model Losses: 0.5584306120872498
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 41173 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.562291145324707
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 76.59%, remaining_weights: 15.24%
#
#  ---- Checking Loss values ----
# Loss: 0.5823156237602234
# Model Losses: 0.767718493938446
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 41370 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.595731735229492
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 89.28%, remaining_weights: 15.09%
#
#  ---- Checking Loss values ----
# Loss: 0.493573933839798
# Model Losses: 0.5758064389228821
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 41567 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.627450942993164
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.92%, remaining_weights: 15.08%
#
#  ---- Checking Loss values ----
# Loss: 0.5319211483001709
# Model Losses: 0.7017292380332947
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 41764 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.659029006958008
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 89.16%, remaining_weights: 15.08%
#
#  ---- Checking Loss values ----
# Loss: 0.3598273694515228
# Model Losses: 0.5862807035446167
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 41961 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.69150161743164
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 75.46%, remaining_weights: 14.93%
#
#  ---- Checking Loss values ----
# Loss: 0.5353606343269348
# Model Losses: 0.6579443216323853
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 42158 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.72203540802002
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 88.54%, remaining_weights: 15.07%
#
#  ---- Checking Loss values ----
# Loss: 0.3845420479774475
# Model Losses: 0.6008699536323547
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 42355 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.755581855773926
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 85.10%, remaining_weights: 14.79%
#
#  ---- Checking Loss values ----
# Loss: 0.4843812882900238
# Model Losses: 0.5883376002311707
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 42552 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.783027648925781
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 87.76%, remaining_weights: 15.09%
#
#  ---- Checking Loss values ----
# Loss: 0.3615413308143616
# Model Losses: 0.6183624863624573
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 42749 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.816713333129883
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 83.89%, remaining_weights: 14.75%
#
#  ---- Checking Loss values ----
# Loss: 0.46583715081214905
# Model Losses: 0.5892390012741089
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 42946 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.844990730285645
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 88.56%, remaining_weights: 15.06%
#
#  ---- Checking Loss values ----
# Loss: 0.4130343496799469
# Model Losses: 0.6410657167434692
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 43143 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.879087448120117
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 83.94%, remaining_weights: 14.63%
#
#  ---- Checking Loss values ----
# Loss: 0.5014403462409973
# Model Losses: 0.547336995601654
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 43340 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.905562400817871
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 86.31%, remaining_weights: 15.12%
#
#  ---- Checking Loss values ----
# Loss: 0.3629485070705414
# Model Losses: 0.6692485213279724
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 43537 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.940855026245117
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 86.46%, remaining_weights: 14.62%
#
#  ---- Checking Loss values ----
# Loss: 0.48859700560569763
# Model Losses: 0.527938723564148
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 43734 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 14.966341018676758
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 86.23%, remaining_weights: 15.17%
#
#  ---- Checking Loss values ----
# Loss: 0.3636632561683655
# Model Losses: 0.7034806609153748
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 43931 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.002158164978027
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 88.59%, remaining_weights: 14.60%
#
#  ---- Checking Loss values ----
# Loss: 0.39036381244659424
# Model Losses: 0.5137195587158203
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 44128 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.026106834411621
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 83.41%, remaining_weights: 15.19%
#
#  ---- Checking Loss values ----
# Loss: 0.43361860513687134
# Model Losses: 0.7346842288970947
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 44325 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.064218521118164
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 88.60%, remaining_weights: 14.57%
#
#  ---- Checking Loss values ----
# Loss: 0.3594304025173187
# Model Losses: 0.504931628704071
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 44522 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.08847713470459
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 84.58%, remaining_weights: 15.23%
#
#  ---- Checking Loss values ----
# Loss: 0.4566643536090851
# Model Losses: 0.7463147044181824
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 44719 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.12496566772461
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 89.96%, remaining_weights: 14.60%
#
#  ---- Checking Loss values ----
# Loss: 0.3546471893787384
# Model Losses: 0.5093618035316467
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 44916 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.148921012878418
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 85.51%, remaining_weights: 15.19%
#
#  ---- Checking Loss values ----
# Loss: 0.4875671863555908
# Model Losses: 0.7559884190559387
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 45113 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.186100006103516
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 90.23%, remaining_weights: 14.56%
#
#  ---- Checking Loss values ----
# Loss: 0.35001471638679504
# Model Losses: 0.4958931803703308
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 45310 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.209214210510254
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 83.10%, remaining_weights: 15.26%
#
#  ---- Checking Loss values ----
# Loss: 0.4185830056667328
# Model Losses: 0.7891981601715088
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 45507 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.24500560760498
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 91.26%, remaining_weights: 14.58%
#
#  ---- Checking Loss values ----
# Loss: 0.3107820153236389
# Model Losses: 0.49246668815612793
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 45704 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.267184257507324
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.10%, remaining_weights: 15.24%
#
#  ---- Checking Loss values ----
# Loss: 0.46560487151145935
# Model Losses: 0.8018596172332764
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 45901 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.302825927734375
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 92.26%, remaining_weights: 14.55%
#
#  ---- Checking Loss values ----
# Loss: 0.27102130651474
# Model Losses: 0.4930519163608551
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 46098 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.324875831604004
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.10%, remaining_weights: 15.32%
#
#  ---- Checking Loss values ----
# Loss: 0.6269076466560364
# Model Losses: 0.9061487913131714
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 46295 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.366178512573242
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 90.74%, remaining_weights: 14.59%
#
#  ---- Checking Loss values ----
# Loss: 0.32408690452575684
# Model Losses: 0.5080901384353638
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 46492 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.388867378234863
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 79.94%, remaining_weights: 15.37%
#
#  ---- Checking Loss values ----
# Loss: 0.5886131525039673
# Model Losses: 0.9024204611778259
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 46689 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.427988052368164
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 91.87%, remaining_weights: 14.61%
#
#  ---- Checking Loss values ----
# Loss: 0.37159013748168945
# Model Losses: 0.5118893384933472
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 46886 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.449933052062988
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 81.17%, remaining_weights: 15.35%
#
#  ---- Checking Loss values ----
# Loss: 0.6258450746536255
# Model Losses: 0.9190372228622437
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 47083 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 15.489151954650879
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------

# %%
#print layers and lmbda weights in the model

for name, layer in model.named_modules():
    if hasattr(layer, "lmbda"):
        print(f"Layer: {name}, lmbda: {layer.lmbda}")

# %%
import numpy as np
from pquant import remove_pruning_from_model
import matplotlib.pyplot as plt
# Remove compression layers, leaves Quantized activations in place
model = remove_pruning_from_model(trained_model, config)

# Plot remaining weights
names = []
remaining = []
total_w = []
nonzeros = []
for n, m in model.named_modules():
    if isinstance(m, (torch.nn.Conv1d, torch.nn.Conv2d, torch.nn.Linear)):
        names.append(n)
        # nonzero = np.count_nonzero(m.weight.detach().cpu())
        nonzero = torch.sum(torch.abs(m.weight.detach().cpu()) > 1e-3).item()
        remaining_pct = nonzero / m.weight.numel()
        remaining.append(remaining_pct)
        total_w.append(m.weight.numel())
        nonzeros.append(nonzero)
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].bar(range(len(names)), remaining)
ax[0].set_xticks(range(len(names)))
ax[0].set_xticklabels(names)
ax[0].tick_params(axis='x', labelrotation=270)
new_ytick = []
for i in ax[0].get_yticklabels():
    ytick = f"{float(i.get_text()) * 100}%"
    new_ytick.append(ytick)
ax[0].set_yticklabels(new_ytick)
ax[0].title.set_text("Remaining weights per layer")

ax[1].bar(range(len(nonzeros)), total_w, color="lightcoral", label="total weights")
ax[1].bar(range(len(nonzeros)), nonzeros, color="steelblue", label="nonzero weights")
ax[1].set_xticks(range(len(names)))
ax[1].set_xticklabels(names)
ax[1].tick_params(axis='x', labelrotation=270)
ax[1].title.set_text("Weights per layer")
ax[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# We see from that with PDP, the number of weights goes down during training, until it reaches the target sparsity (sparsity of 80%, or ~20% remaining weights). The function that calculates the remaining weights feeds the weights through the quantizer and pruning method, and calculates the ratio between non-zero weights and all weights. However, since PDP uses a soft mask during training, the percentage of remaining weights seems to go down rather noisily (can even drop from 80% to ~20% remaining weights). The algorithm actually increases the sparsity linearly.
# During fine-tuning the mask is fixed, and turned into a mask of 0s and 1s by a simple rounding operation, so the remaining weights stay the same during each epoch.
#
# In the original paper for PDP there was no fine-tuning after the creation of the final hard mask. We have added fine-tuning here as an option that can be turned off by simply setting ```fine_tuning_epochs``` to 0 in the config file.

# %%
import numpy as np
from pquant import remove_pruning_from_model
import matplotlib.pyplot as plt
# Remove compression layers, leaves Quantized activations in place
model = remove_pruning_from_model(trained_model, config)

# Plot remaining weights
names = []
remaining = []
total_w = []
nonzeros = []
for n, m in trained_model.named_modules():
    if isinstance(m, (torch.nn.Conv1d, torch.nn.Conv2d, torch.nn.Linear)):
        names.append(n)
        nonzero = np.count_nonzero(m.weight.detach().cpu())
        remaining_pct = nonzero / m.weight.numel()
        remaining.append(remaining_pct)
        total_w.append(m.weight.numel())
        nonzeros.append(nonzero)
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].bar(range(len(names)), remaining)
ax[0].set_xticks(range(len(names)))
ax[0].set_xticklabels(names)
ax[0].tick_params(axis='x', labelrotation=270)
new_ytick = []
for i in ax[0].get_yticklabels():
    ytick = f"{float(i.get_text()) * 100}%"
    new_ytick.append(ytick)
ax[0].set_yticklabels(new_ytick)
ax[0].title.set_text("Remaining weights per layer")

ax[1].bar(range(len(nonzeros)), total_w, color="lightcoral", label="total weights")
ax[1].bar(range(len(nonzeros)), nonzeros, color="steelblue", label="nonzero weights")
ax[1].set_xticks(range(len(names)))
ax[1].set_xticklabels(names)
ax[1].tick_params(axis='x', labelrotation=270)
ax[1].title.set_text("Weights per layer")
ax[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Custom config from existing config
# Using the ```pquant/configs/config_pdp.yaml``` as base, let's customize the quantization and pruning scheme.
#
# The function we use will go through the model's layers and do the following:
#
# Quantization:
#
#         1. Looks for the names of convolutional and linear layers, as well as names of the activations (layer type activations and functional types)
#         2. Adds the name of the layer to the layer_specific list, along with a default quantization scheme of 0 and 7 for weight and bias (if bias is not None)
#
# Pruning:
#
#         1. Looks for convolutional and linear layers and adds their name to the disable_pruning_for_layers list.

# %%
# Base config
pruning_method = "pdp"
config = get_default_config(pruning_method)
model = torchvision.models.resnet18()


from pquant import add_default_layer_quantization_pruning_to_config
config = add_default_layer_quantization_pruning_to_config(model, config)
config

# %%
# Save config
from pquant.core.utils import write_config_to_yaml
write_config_to_yaml(config, "prune_quantize_example.yaml", sort_keys=False)

# %% [markdown]
# Now that we have the custom config, it is up to us to modify the quantization bits for each layer that will not use the default value. If a layer uses the default value it can be removed from the ```layer_specific``` list.
#
# For pruning, leave those layers to the ```disable_pruning_for_layers``` list that will not be pruned, others need to be removed from the list.

# %% [markdown]
# ## About replacing layers and activations
# Layers that can currently be compressed: ```nn.Conv1d, nn.Conv2d, nn.Linear```.
#
# Activations that can currently be automatically be replaced with a quantized variant: ```nn.ReLU, nn.Tanh```. The activations are replaced by a quantized variant, found in ```pquant.core.activations_quantizer.py```.

# %% [markdown]
# ## More about activations
# If using layer type activations, note that if you want to keep the fine-grained control over the quantization of the activation, reusing an activation layer can cause problems, as all activations will use the quantization bits set for that particular layer. To avoid this, use a separate ```nn.Tanh``` / ```nn.ReLU``` for each activation

# %% [markdown]
# ## HGQ
# To use HGQ, enable it in the config: `config["quantization_parameters"]["use_high_granularity_quantization"] = True`. Other relevant parameters to tune are `config["quantization_parameters"]["default_integer_bits"]`, `config["quantization_parameters"]["default_fractional_bits"]`, `config["quantization_parameters"]["hgq_gamma"]`.
# When using HGQ, we advice using Adam instead of SGD as an optimizer.
