# %% [markdown]
# ## In this tutorial we create a CNN and dataloaders, and train / prune the model.

# %%
import os
os.environ["KERAS_BACKEND"] = "torch" # Needs to be set, some pruning layers as well as the quantizers are Keras
import keras
keras.config.set_backend("torch")
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
keras.backend.set_image_data_format("channels_first")
# Out:
# /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
os.chdir("/home/das214/PQuant/MDMM/src")

# %%
model = torchvision.models.resnet18()
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
model = model.to(device)

model
# Out:
# Using device: cuda
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# ## Add pruning and quantization
# To add pruning and quantization, we need a config file that defines how to do that. Let's load a config file from pquant/configs/configs_pdp.yaml. The training function we use later will add the pruning layers and quantized activations automatically using this config

# %%
from pquant import get_default_config

# pruning_methods: "autosparse, cl, cs, dst, pdp, wanda"
pruning_method = "mdmm"
config = get_default_config(pruning_method)
# Set target sparsity to 80% (20% of weights are non-zero). This parameter exists only for some pruning methods
config["pruning_parameters"]["sparsity"] = 0.8
# Check what's inside the config
config
# Out:
# {'pruning_parameters': {'pruning_method': 'mdmm',
#   'enable_pruning': True,
#   'disable_pruning_for_layers': [None],
#   'constraint_type': 'Equality',
#   'target_value': 0.0,
#   'metric_type': 'UnstructuredSparsity',
#   'target_sparsity': 0.9,
#   'rf': 1,
#   'epsilon': 0.001,
#   'scale': 10.0,
#   'damping': 1.0,
#   'use_grad': False,
#   'l0_mode': 'coarse',
#   'sparsity': 0.8},
#  'quantization_parameters': {'enable_quantization': False,
#   'default_integer_bits': 0.0,
#   'default_fractional_bits': 7.0,
#   'hgq_gamma': 0.0003,
#   'hgq_heterogeneous': True,
#   'layer_specific': [],
#   'use_high_granularity_quantization': False,
#   'use_real_tanh': False,
#   'use_symmetric_quantization': False},
#  'training_parameters': {'epochs': 300,
#   'fine_tuning_epochs': 0,
#   'pretraining_epochs': 0,
#   'pruning_first': False,
#   'rewind': 'never',
#   'rounds': 1,
#   'save_weights_epoch': -1},
#  'batch_size': 128,
#  'cosine_tmax': 200,
#  'gamma': 0.1,
#  'l2_decay': 0.0001,
#  'label_smoothing': 0.0,
#  'lr': 0.01,
#  'lr_schedule': 'multistep',
#  'milestones': [75, 120],
#  'momentum': 0.9,
#  'optimizer': 'sgd',
#  'plot_frequency': 100}

# %%
# Replace layers with compressed layers
from pquant import add_compression_layers
input_shape = (256,3,32,32)
model = add_compression_layers(model, config, input_shape)
model
# Out:
# ResNet(
#   (conv1): CompressedLayerConv2d(
#     (pruning_layer): <MDMM name=mdmm, built=True>
#   )
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_1, built=True>
#       )
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_2, built=True>
#       )
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_3, built=True>
#       )
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_4, built=True>
#       )
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_5, built=True>
#       )
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_6, built=True>
#       )
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): CompressedLayerConv2d(
#           (pruning_layer): <MDMM name=mdmm_7, built=True>
#         )
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_8, built=True>
#       )
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_9, built=True>
#       )
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_10, built=True>
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_11, built=True>
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): CompressedLayerConv2d(
#           (pruning_layer): <MDMM name=mdmm_12, built=True>
#         )
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_13, built=True>
#       )
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_14, built=True>
#       )
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_15, built=True>
#       )
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_16, built=True>
#       )
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): CompressedLayerConv2d(
#           (pruning_layer): <MDMM name=mdmm_17, built=True>
#         )
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_18, built=True>
#       )
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): CompressedLayerConv2d(
#         (pruning_layer): <MDMM name=mdmm_19, built=True>
#       )
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): CompressedLayerLinear(
#     (pruning_layer): <MDMM name=mdmm_20, built=True>
#   )
# )

# %% [markdown]
# ## Pruning and quantization in the config
# From the config we see that we are using the PDP pruning method, unstructured version. We aim for 80% weights pruned (sparsity 0.8), and we quantize the model to 8 bits (1 bit goes to sign).
# By default, all convolutional and linear layers, as well as activations will be quantized using the default values ```default_integer_bits``` and ```default_fractional_bits```. Similarly, by default all convolutional and linear layers will be pruned.
#
# We can disable pruning and/or quantization by setting the enable_pruning / enable_quantization to False. To change quantization bits for a specific layer, add the layers name to the list found in ```layer_specific```, followed by number of bits. To disable pruning for a single layer, add its name to the ```disable_pruning_for_layers``` list.
#
# We'll show later how to create a custom quantization / pruning config file from an existing config for a given model

# %% [markdown]
# ## About the different epochs
#
# The config defines 20 ```pretraining_epochs```, 100 ```epochs``` and 20 ```fine_tuning_epochs```. What happens during each of these training steps is algorithm specific.
#
# In PDP, the pretraining phase consists of training without pruning, followed by calculation of layerwise pruning budgets. After pretraining is finished and the layerwise pruning budgets have been calculated, the training with pruning begins. The mask during this training is a soft mask, consisting of values ranging between (and including) 0 and 1.
#
# The fine-tuning step in PDP is optional (not mentioned in the original paper), and during it the mask is fixed and rounded to 0s and 1s.

# %% [markdown]
# ## Create data set
# #### Let's create the data loader and the training and validation loops

# %%
import torchvision.transforms as transforms

def get_cifar10_data(batch_size):
    normalize = transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    train_transform = transforms.Compose([transforms.RandomHorizontalFlip(), transforms.RandomCrop(32, padding=4), 
                                          transforms.ToTensor(), normalize])
    test_transform = transforms.Compose([transforms.ToTensor(), normalize])  
    trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=train_transform)
    valset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                       download=True, transform=test_transform)
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=4, pin_memory=True)

    val_loader = torch.utils.data.DataLoader(valset, batch_size=batch_size,
                                         shuffle=False, num_workers=4, pin_memory=True)

    return train_loader, val_loader

from quantizers.fixed_point.fixed_point_ops import get_fixed_quantizer
# Set up input quantizer
quantizer = get_fixed_quantizer(overflow_mode="SAT")


def train_resnet(model, trainloader, device, loss_func, epoch, optimizer, scheduler, *args, **kwargs):
    first_batch = True
    for data in trainloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        inputs = quantizer(inputs, k=torch.tensor(1.), i=torch.tensor(0.), f=torch.tensor(7.)) # 8 bits input quantization
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_func(outputs, labels)
        losses = get_model_losses(model, torch.tensor(0.).to(device))
        loss += losses
        loss.backward()
        
        if first_batch:
            print("\n ---- Checking Loss values ----")
            print("Loss:", loss_func(outputs, labels).item())
            print("Model Losses:", losses.item())
            print("--------------------------------------------------")
            print(f"\n--- Checking Gradients for lmbda at Epoch {epoch} ---")
            for name, module in model.named_modules():
                if "pruning_layer.constraint_layer.module" in name and hasattr(module, "lmbda"):
                    # Access the underlying tensor via the '.value' attribute
                    underlying_tensor = module.lmbda.value
                    grad_value = underlying_tensor.grad
                    print(f"Layer: {name}, lmbda: {underlying_tensor.item()}")
                    if grad_value is not None:
                        print(f"Layer: {name}, Gradient: {grad_value.item()}")
                    else:
                        print(f"Layer: {name}, Gradient: None")
                        
                    break
            print("--------------------------------------------------\n")
            first_batch = False
            
        optimizer.step()
        epoch += 1
        if scheduler is not None:
            scheduler.step()


from pquant import get_layer_keep_ratio, get_model_losses

def validate_resnet(model, testloader, device, loss_func, epoch, *args, **kwargs):
    correct = 0
    total = 0
    model.eval()
    with torch.no_grad():
        for data in testloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            inputs = quantizer(inputs, k=torch.tensor(1.), i=torch.tensor(0.), f=torch.tensor(7.)) # 8 bits input quantization
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        ratio = get_layer_keep_ratio(model)
        print(f'Accuracy: {100 * correct / total:.2f}%, remaining_weights: {ratio * 100:.2f}%')

BATCH_SIZE = 256
train_loader, val_loader = get_cifar10_data(BATCH_SIZE)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:02<00:00, 69620261.86it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Create loss function, scheduler and optimizer

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR

optimizer = torch.optim.SGD(model.parameters(), lr=0.01, weight_decay=0.0001, momentum=0.9)
scheduler = CosineAnnealingLR(optimizer, 200)
loss_function = nn.CrossEntropyLoss()

# %% [markdown]
# ## Train model
# Training time. We use the train_compressed_model function from pquant to train. We need to provide some parameters such as training and validation functions, their input parameters, the model and the config file. The function automatically adds pruning layers and replaces activations with a quantized variant, trains the model, and removes the pruning layers after training is done

# %%
from pquant import iterative_train
"""
Inputs to train_resnet we defined previously are:
          model, trainloader, device, loss_func, epoch, optimizer, scheduler, **kwargs
"""

trained_model = iterative_train(model = model, 
                                config = config, 
                                train_func = train_resnet, 
                                valid_func = validate_resnet, 
                                trainloader = train_loader, 
                                testloader = val_loader, 
                                device = device, 
                                loss_func = loss_function,
                                optimizer = optimizer, 
                                scheduler = scheduler
                                )
# Out:
#  ---- Checking Loss values ----
# Loss: 7.135669231414795
# Model Losses: 6.162947654724121
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 0 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 1.0016192197799683
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 47.55%, remaining_weights: 96.31%
#
#  ---- Checking Loss values ----
# Loss: 1.5530200004577637
# Model Losses: 13.937422752380371
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 197 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 1.6875063180923462
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 44.25%, remaining_weights: 95.79%
#
#  ---- Checking Loss values ----
# Loss: 1.473468542098999
# Model Losses: 17.73257827758789
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 394 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.1771180629730225
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 58.23%, remaining_weights: 94.89%
#
#  ---- Checking Loss values ----
# Loss: 1.2197918891906738
# Model Losses: 17.910266876220703
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 591 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.4376912117004395
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 48.61%, remaining_weights: 94.22%
#
#  ---- Checking Loss values ----
# Loss: 1.3763700723648071
# Model Losses: 18.804590225219727
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 788 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.6908600330352783
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.56%, remaining_weights: 92.74%
#
#  ---- Checking Loss values ----
# Loss: 1.0695103406906128
# Model Losses: 16.597980499267578
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 985 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 2.896994113922119
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 50.49%, remaining_weights: 92.14%
#
#  ---- Checking Loss values ----
# Loss: 1.2552869319915771
# Model Losses: 17.319602966308594
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1182 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.1198978424072266
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.69%, remaining_weights: 90.18%
#
#  ---- Checking Loss values ----
# Loss: 1.05397367477417
# Model Losses: 14.713211059570312
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1379 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.301238536834717
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 52.93%, remaining_weights: 89.64%
#
#  ---- Checking Loss values ----
# Loss: 1.152192234992981
# Model Losses: 15.551294326782227
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1576 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.4971225261688232
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 68.03%, remaining_weights: 87.40%
#
#  ---- Checking Loss values ----
# Loss: 0.9102700352668762
# Model Losses: 13.158321380615234
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1773 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.6637566089630127
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 40.60%, remaining_weights: 86.94%
#
#  ---- Checking Loss values ----
# Loss: 1.497860074043274
# Model Losses: 13.909842491149902
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 1970 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.839973211288452
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 68.06%, remaining_weights: 84.47%
#
#  ---- Checking Loss values ----
# Loss: 1.0803368091583252
# Model Losses: 11.813858985900879
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2167 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 3.9916326999664307
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 59.47%, remaining_weights: 84.18%
#
#  ---- Checking Loss values ----
# Loss: 1.2642122507095337
# Model Losses: 12.582046508789062
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2364 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.146646022796631
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.33%, remaining_weights: 81.54%
#
#  ---- Checking Loss values ----
# Loss: 1.0152612924575806
# Model Losses: 10.77096939086914
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2561 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.289273262023926
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 46.45%, remaining_weights: 81.17%
#
#  ---- Checking Loss values ----
# Loss: 1.1575126647949219
# Model Losses: 11.30036449432373
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2758 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.419325351715088
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.64%, remaining_weights: 78.45%
#
#  ---- Checking Loss values ----
# Loss: 0.9119117856025696
# Model Losses: 9.824216842651367
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 2955 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.550624370574951
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 55.81%, remaining_weights: 78.10%
#
#  ---- Checking Loss values ----
# Loss: 1.1687668561935425
# Model Losses: 10.277495384216309
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3152 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.67238187789917
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.32%, remaining_weights: 75.44%
#
#  ---- Checking Loss values ----
# Loss: 0.9304748773574829
# Model Losses: 9.037099838256836
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3349 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.793821334838867
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 54.83%, remaining_weights: 74.92%
#
#  ---- Checking Loss values ----
# Loss: 1.2778830528259277
# Model Losses: 9.295344352722168
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3546 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 4.901368618011475
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.98%, remaining_weights: 72.45%
#
#  ---- Checking Loss values ----
# Loss: 0.9086226224899292
# Model Losses: 8.341687202453613
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3743 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.018751621246338
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 55.92%, remaining_weights: 71.77%
#
#  ---- Checking Loss values ----
# Loss: 1.0908864736557007
# Model Losses: 8.450424194335938
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 3940 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.119160175323486
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.94%, remaining_weights: 69.44%
#
#  ---- Checking Loss values ----
# Loss: 0.9530574083328247
# Model Losses: 7.687025547027588
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4137 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.24003791809082
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 57.12%, remaining_weights: 68.49%
#
#  ---- Checking Loss values ----
# Loss: 1.073759913444519
# Model Losses: 7.547393321990967
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4334 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.326282501220703
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.97%, remaining_weights: 66.58%
#
#  ---- Checking Loss values ----
# Loss: 1.1019119024276733
# Model Losses: 7.089367866516113
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4531 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.4379754066467285
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 61.49%, remaining_weights: 65.42%
#
#  ---- Checking Loss values ----
# Loss: 0.9010800719261169
# Model Losses: 6.838486194610596
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4728 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.518195629119873
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.53%, remaining_weights: 63.75%
#
#  ---- Checking Loss values ----
# Loss: 0.9031938910484314
# Model Losses: 6.564751625061035
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 4925 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.63107967376709
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.85%, remaining_weights: 62.37%
#
#  ---- Checking Loss values ----
# Loss: 0.9854605197906494
# Model Losses: 6.175296306610107
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5122 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.701956748962402
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 57.34%, remaining_weights: 61.04%
#
#  ---- Checking Loss values ----
# Loss: 0.9891877174377441
# Model Losses: 6.078005790710449
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5319 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.810709476470947
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 70.90%, remaining_weights: 59.48%
#
#  ---- Checking Loss values ----
# Loss: 0.8716769814491272
# Model Losses: 5.5946784019470215
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5516 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.877072334289551
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 60.71%, remaining_weights: 58.50%
#
#  ---- Checking Loss values ----
# Loss: 0.993428111076355
# Model Losses: 5.695908546447754
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5713 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 5.987862586975098
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 72.27%, remaining_weights: 56.72%
#
#  ---- Checking Loss values ----
# Loss: 0.8872119188308716
# Model Losses: 5.094114780426025
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 5910 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.054192543029785
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 61.32%, remaining_weights: 55.96%
#
#  ---- Checking Loss values ----
# Loss: 1.2037417888641357
# Model Losses: 5.33009672164917
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6107 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.168990135192871
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 73.30%, remaining_weights: 54.12%
#
#  ---- Checking Loss values ----
# Loss: 0.7733863592147827
# Model Losses: 4.640347480773926
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6304 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.225524425506592
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 60.83%, remaining_weights: 53.58%
#
#  ---- Checking Loss values ----
# Loss: 0.9637348055839539
# Model Losses: 4.951457977294922
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6501 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.332611083984375
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 72.94%, remaining_weights: 51.64%
#
#  ---- Checking Loss values ----
# Loss: 0.7725985646247864
# Model Losses: 4.237298965454102
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6698 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.388078212738037
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 59.53%, remaining_weights: 51.34%
#
#  ---- Checking Loss values ----
# Loss: 0.9983828067779541
# Model Losses: 4.664648532867432
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 6895 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.501108169555664
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 74.97%, remaining_weights: 49.35%
#
#  ---- Checking Loss values ----
# Loss: 0.7429139018058777
# Model Losses: 3.886056661605835
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7092 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.554006576538086
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 55.75%, remaining_weights: 49.10%
#
#  ---- Checking Loss values ----
# Loss: 1.319738507270813
# Model Losses: 4.31575345993042
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7289 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.658578395843506
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 75.57%, remaining_weights: 47.08%
#
#  ---- Checking Loss values ----
# Loss: 0.7411822080612183
# Model Losses: 3.5450501441955566
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7486 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.70587158203125
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 57.82%, remaining_weights: 47.13%
#
#  ---- Checking Loss values ----
# Loss: 1.0657274723052979
# Model Losses: 4.0904364585876465
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7683 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.812361717224121
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.50%, remaining_weights: 45.03%
#
#  ---- Checking Loss values ----
# Loss: 0.701683521270752
# Model Losses: 3.269688844680786
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 7880 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.8609299659729
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 50.00%, remaining_weights: 45.14%
#
#  ---- Checking Loss values ----
# Loss: 1.085672378540039
# Model Losses: 3.7358453273773193
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8077 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 6.956353664398193
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.11%, remaining_weights: 43.11%
#
#  ---- Checking Loss values ----
# Loss: 0.794931173324585
# Model Losses: 3.018047571182251
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8274 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.006760120391846
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 60.66%, remaining_weights: 43.20%
#
#  ---- Checking Loss values ----
# Loss: 1.1622207164764404
# Model Losses: 3.4763519763946533
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8471 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.097282409667969
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.47%, remaining_weights: 41.25%
#
#  ---- Checking Loss values ----
# Loss: 0.7685564160346985
# Model Losses: 2.7756052017211914
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8668 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.1490559577941895
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 61.44%, remaining_weights: 41.58%
#
#  ---- Checking Loss values ----
# Loss: 0.9776176810264587
# Model Losses: 3.302197217941284
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 8865 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.245971202850342
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.81%, remaining_weights: 39.49%
#
#  ---- Checking Loss values ----
# Loss: 0.5960414409637451
# Model Losses: 2.545964002609253
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9062 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.298089981079102
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 58.59%, remaining_weights: 39.89%
#
#  ---- Checking Loss values ----
# Loss: 0.9257349967956543
# Model Losses: 3.076462984085083
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9259 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.387115478515625
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.90%, remaining_weights: 37.89%
#
#  ---- Checking Loss values ----
# Loss: 0.6959633231163025
# Model Losses: 2.3532021045684814
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9456 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.440027713775635
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 57.08%, remaining_weights: 38.37%
#
#  ---- Checking Loss values ----
# Loss: 1.0464696884155273
# Model Losses: 2.9138622283935547
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9653 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.529893398284912
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 79.06%, remaining_weights: 36.39%
#
#  ---- Checking Loss values ----
# Loss: 0.7014057636260986
# Model Losses: 2.1664397716522217
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 9850 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.584156513214111
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 56.26%, remaining_weights: 36.93%
#
#  ---- Checking Loss values ----
# Loss: 1.0548923015594482
# Model Losses: 2.719081163406372
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10047 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.668927192687988
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.99%, remaining_weights: 35.00%
#
#  ---- Checking Loss values ----
# Loss: 0.6229885220527649
# Model Losses: 2.004364013671875
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10244 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.7226481437683105
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.98%, remaining_weights: 35.61%
#
#  ---- Checking Loss values ----
# Loss: 1.0190688371658325
# Model Losses: 2.582181453704834
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10441 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.80303430557251
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 79.33%, remaining_weights: 33.71%
#
#  ---- Checking Loss values ----
# Loss: 0.6061251163482666
# Model Losses: 1.862212061882019
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10638 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.857936859130859
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 59.43%, remaining_weights: 34.29%
#
#  ---- Checking Loss values ----
# Loss: 0.9302524924278259
# Model Losses: 2.3923089504241943
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 10835 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.935307025909424
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.57%, remaining_weights: 32.49%
#
#  ---- Checking Loss values ----
# Loss: 0.640023946762085
# Model Losses: 1.7318400144577026
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11032 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 7.9914374351501465
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 56.92%, remaining_weights: 33.00%
#
#  ---- Checking Loss values ----
# Loss: 0.9545021653175354
# Model Losses: 2.204810857772827
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11229 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.061088562011719
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.63%, remaining_weights: 31.41%
#
#  ---- Checking Loss values ----
# Loss: 0.6271704435348511
# Model Losses: 1.6226224899291992
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11426 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.11899185180664
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.22%, remaining_weights: 31.72%
#
#  ---- Checking Loss values ----
# Loss: 0.9538021683692932
# Model Losses: 2.0489931106567383
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11623 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.189262390136719
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.88%, remaining_weights: 30.43%
#
#  ---- Checking Loss values ----
# Loss: 0.674359142780304
# Model Losses: 1.5366233587265015
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 11820 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.24677848815918
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.79%, remaining_weights: 30.72%
#
#  ---- Checking Loss values ----
# Loss: 0.9498701095581055
# Model Losses: 1.9486334323883057
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12017 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.316072463989258
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.08%, remaining_weights: 29.51%
#
#  ---- Checking Loss values ----
# Loss: 0.6312304735183716
# Model Losses: 1.4593971967697144
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12214 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.3748140335083
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.46%, remaining_weights: 29.68%
#
#  ---- Checking Loss values ----
# Loss: 0.8641992211341858
# Model Losses: 1.8073949813842773
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12411 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.437522888183594
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.50%, remaining_weights: 28.67%
#
#  ---- Checking Loss values ----
# Loss: 0.6629183292388916
# Model Losses: 1.4059637784957886
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12608 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.499241828918457
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.95%, remaining_weights: 28.57%
#
#  ---- Checking Loss values ----
# Loss: 1.0029963254928589
# Model Losses: 1.6324405670166016
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 12805 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.557951927185059
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 76.56%, remaining_weights: 27.96%
#
#  ---- Checking Loss values ----
# Loss: 0.6765831708908081
# Model Losses: 1.350986361503601
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13002 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.620331764221191
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.89%, remaining_weights: 27.69%
#
#  ---- Checking Loss values ----
# Loss: 0.8423302173614502
# Model Losses: 1.5036773681640625
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13199 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.675758361816406
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.10%, remaining_weights: 27.27%
#
#  ---- Checking Loss values ----
# Loss: 0.6572454571723938
# Model Losses: 1.3202540874481201
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13396 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.742701530456543
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.21%, remaining_weights: 26.89%
#
#  ---- Checking Loss values ----
# Loss: 0.8018423318862915
# Model Losses: 1.4036493301391602
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13593 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.794471740722656
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 73.30%, remaining_weights: 26.66%
#
#  ---- Checking Loss values ----
# Loss: 0.7485899329185486
# Model Losses: 1.3033770322799683
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13790 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.860954284667969
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 69.95%, remaining_weights: 26.05%
#
#  ---- Checking Loss values ----
# Loss: 0.8175933957099915
# Model Losses: 1.2709364891052246
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 13987 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.910499572753906
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 72.98%, remaining_weights: 26.13%
#
#  ---- Checking Loss values ----
# Loss: 0.6631259918212891
# Model Losses: 1.277927041053772
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14184 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 8.977530479431152
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 72.49%, remaining_weights: 25.34%
#
#  ---- Checking Loss values ----
# Loss: 0.7087779641151428
# Model Losses: 1.148750901222229
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14381 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.023205757141113
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 73.98%, remaining_weights: 25.63%
#
#  ---- Checking Loss values ----
# Loss: 0.8128352165222168
# Model Losses: 1.2893837690353394
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14578 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.092314720153809
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 70.75%, remaining_weights: 24.74%
#
#  ---- Checking Loss values ----
# Loss: 0.7327076196670532
# Model Losses: 1.0549538135528564
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14775 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.132901191711426
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.75%, remaining_weights: 25.20%
#
#  ---- Checking Loss values ----
# Loss: 0.8468059301376343
# Model Losses: 1.298631191253662
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 14972 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.207051277160645
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 74.25%, remaining_weights: 24.16%
#
#  ---- Checking Loss values ----
# Loss: 0.7762042284011841
# Model Losses: 0.9697324633598328
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15169 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.245579719543457
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 72.25%, remaining_weights: 24.72%
#
#  ---- Checking Loss values ----
# Loss: 0.841468870639801
# Model Losses: 1.259462594985962
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15366 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.315569877624512
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 78.35%, remaining_weights: 23.66%
#
#  ---- Checking Loss values ----
# Loss: 0.7358664870262146
# Model Losses: 0.9124928712844849
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15563 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.3511323928833
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.86%, remaining_weights: 24.37%
#
#  ---- Checking Loss values ----
# Loss: 0.7611461281776428
# Model Losses: 1.3166874647140503
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15760 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.425346374511719
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 77.89%, remaining_weights: 23.24%
#
#  ---- Checking Loss values ----
# Loss: 0.5513540506362915
# Model Losses: 0.8721441626548767
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 15957 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.460668563842773
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 70.73%, remaining_weights: 23.97%
#
#  ---- Checking Loss values ----
# Loss: 0.7739342451095581
# Model Losses: 1.2782659530639648
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16154 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.5299654006958
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 80.47%, remaining_weights: 22.85%
#
#  ---- Checking Loss values ----
# Loss: 0.6690242290496826
# Model Losses: 0.8292127251625061
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16351 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.562464714050293
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 68.81%, remaining_weights: 23.77%
#
#  ---- Checking Loss values ----
# Loss: 0.8778529763221741
# Model Losses: 1.3262853622436523
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16548 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.634142875671387
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 81.51%, remaining_weights: 22.53%
#
#  ---- Checking Loss values ----
# Loss: 0.573573887348175
# Model Losses: 0.8122068643569946
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16745 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.666911125183105
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 70.62%, remaining_weights: 23.36%
#
#  ---- Checking Loss values ----
# Loss: 0.7717639803886414
# Model Losses: 1.2795976400375366
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 16942 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.737225532531738
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.07%, remaining_weights: 22.17%
#
#  ---- Checking Loss values ----
# Loss: 0.6372246742248535
# Model Losses: 0.7925078868865967
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17139 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.769928932189941
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 69.99%, remaining_weights: 23.11%
#
#  ---- Checking Loss values ----
# Loss: 0.9566460251808167
# Model Losses: 1.3329980373382568
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17336 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.844951629638672
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.56%, remaining_weights: 21.86%
#
#  ---- Checking Loss values ----
# Loss: 0.6190944910049438
# Model Losses: 0.769150972366333
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17533 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.877703666687012
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.98%, remaining_weights: 22.70%
#
#  ---- Checking Loss values ----
# Loss: 0.8110852837562561
# Model Losses: 1.2836599349975586
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17730 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.945860862731934
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.70%, remaining_weights: 21.51%
#
#  ---- Checking Loss values ----
# Loss: 0.6044057011604309
# Model Losses: 0.7479564547538757
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 17927 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 9.978082656860352
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.50%, remaining_weights: 22.51%
#
#  ---- Checking Loss values ----
# Loss: 0.834843635559082
# Model Losses: 1.3282248973846436
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18124 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.04903793334961
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.98%, remaining_weights: 21.28%
#
#  ---- Checking Loss values ----
# Loss: 0.57686448097229
# Model Losses: 0.7501240372657776
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18321 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.084136009216309
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 65.19%, remaining_weights: 22.19%
#
#  ---- Checking Loss values ----
# Loss: 0.9327408671379089
# Model Losses: 1.3149209022521973
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18518 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.151198387145996
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.66%, remaining_weights: 20.96%
#
#  ---- Checking Loss values ----
# Loss: 0.47222185134887695
# Model Losses: 0.7403108477592468
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18715 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.188274383544922
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.70%, remaining_weights: 21.82%
#
#  ---- Checking Loss values ----
# Loss: 0.8849191665649414
# Model Losses: 1.2709994316101074
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 18912 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.256988525390625
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 83.07%, remaining_weights: 20.63%
#
#  ---- Checking Loss values ----
# Loss: 0.5955505967140198
# Model Losses: 0.7235355973243713
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19109 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.295015335083008
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 64.10%, remaining_weights: 21.50%
#
#  ---- Checking Loss values ----
# Loss: 0.9517561793327332
# Model Losses: 1.2591227293014526
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19306 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.359942436218262
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.84%, remaining_weights: 20.38%
#
#  ---- Checking Loss values ----
# Loss: 0.5674176812171936
# Model Losses: 0.7090506553649902
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19503 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.397831916809082
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 62.20%, remaining_weights: 21.20%
#
#  ---- Checking Loss values ----
# Loss: 0.905759871006012
# Model Losses: 1.2405518293380737
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19700 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.461920738220215
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 83.18%, remaining_weights: 20.10%
#
#  ---- Checking Loss values ----
# Loss: 0.6857441067695618
# Model Losses: 0.6850264668464661
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 19897 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.501089096069336
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 67.80%, remaining_weights: 20.88%
#
#  ---- Checking Loss values ----
# Loss: 0.7272734045982361
# Model Losses: 1.1758936643600464
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20094 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.5596923828125
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 83.52%, remaining_weights: 19.93%
#
#  ---- Checking Loss values ----
# Loss: 0.5139902234077454
# Model Losses: 0.6958895921707153
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20291 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.60035514831543
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 68.05%, remaining_weights: 20.61%
#
#  ---- Checking Loss values ----
# Loss: 0.7718735337257385
# Model Losses: 1.1965454816818237
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20488 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.661321640014648
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 83.30%, remaining_weights: 19.69%
#
#  ---- Checking Loss values ----
# Loss: 0.5568463802337646
# Model Losses: 0.6772346496582031
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20685 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.702193260192871
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.25%, remaining_weights: 20.36%
#
#  ---- Checking Loss values ----
# Loss: 0.7891132235527039
# Model Losses: 1.152984380722046
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 20882 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.758419036865234
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 82.65%, remaining_weights: 19.46%
#
#  ---- Checking Loss values ----
# Loss: 0.6334272027015686
# Model Losses: 0.6729409694671631
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 21079 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.80141544342041
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 63.53%, remaining_weights: 19.90%
#
#  ---- Checking Loss values ----
# Loss: 0.7533980011940002
# Model Losses: 1.0387287139892578
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 21276 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.854081153869629
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 83.11%, remaining_weights: 19.33%
#
#  ---- Checking Loss values ----
# Loss: 0.611344575881958
# Model Losses: 0.6784488558769226
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 21473 ---
# Layer: conv1.pruning_layer.constraint_layer.module, lmbda: 10.897747993469238
# Layer: conv1.pruning_layer.constraint_layer.module, Gradient: None
# --------------------------------------------------
#
# Accuracy: 66.11%, remaining_weights: 19.70%
#
#  ---- Checking Loss values ----
# Loss: 0.7350359559059143
# Model Losses: 1.0579347610473633
# --------------------------------------------------
#
# --- Checking Gradients for lmbda at Epoch 21670 ---
# ...
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torchvision/models/resnet.py:96, in BasicBlock.forward(self, x)
#      93 out = self.bn1(out)
#      94 out = self.relu(out)
# ---> 96 out = self.conv2(out)
#      97 out = self.bn2(out)
#      99 if self.downsample is not None:
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/PQuant/MDMM/src/pquant/core/torch_impl/compressed_layers_torch.py:161, in CompressedLayerConv2d.forward(self, x)
#     160 def forward(self, x):
# --> 161     weight, bias = self.prune_and_quantize(self.weight, self.bias)
#     162     if self.pruning_method == "wanda":
#     163         self.pruning_layer.collect_input(x, weight, self.training)
#
# File ~/PQuant/MDMM/src/pquant/core/torch_impl/compressed_layers_torch.py:119, in CompressedLayerBase.prune_and_quantize(self, weight, bias)
#     117 else:
#     118     weight, bias = self.quantize(weight, bias)
# --> 119     weight = self.prune(weight)
#     120 return weight, bias
#
# File ~/PQuant/MDMM/src/pquant/core/torch_impl/compressed_layers_torch.py:110, in CompressedLayerBase.prune(self, weight)
#     108 def prune(self, weight):
#     109     if self.enable_pruning:
# --> 110         weight = self.pruning_layer(weight)
#     111     return weight
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/layers/layer.py:936, in Layer.__call__(self, *args, **kwargs)
#     934         outputs = super().__call__(*args, **kwargs)
#     935 else:
# --> 936     outputs = super().__call__(*args, **kwargs)
#     937 # Change the layout for the layer output if needed.
#     938 # This is useful for relayout intermediate tensor in the model
#     939 # to achieve the optimal performance.
#     940 distribution = distribution_lib.distribution()
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/backend/torch/layer.py:41, in TorchLayer.forward(self, *args, **kwargs)
#      40 def forward(self, *args, **kwargs):
# ---> 41     return Operation.__call__(self, *args, **kwargs)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/ops/operation.py:58, in Operation.__call__(self, *args, **kwargs)
#      53                 call_fn = self.call
#      54     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      55         call_fn,
#      56         object_name=(f"{self.__class__.__name__}.call()"),
#      57     )
# ---> 58     return call_fn(*args, **kwargs)
#      60 # Plain flow.
#      61 if any_symbolic_tensors(args, kwargs):
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/PQuant/MDMM/src/pquant/pruning_methods/mdmm.py:272, in MDMM.call(self, weight)
#     269 if not self.built:
#     270     self.build(weight.shape)
# --> 272 self.penalty_loss = self.constraint_layer(weight)
#     274 return weight
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/layers/layer.py:936, in Layer.__call__(self, *args, **kwargs)
#     934         outputs = super().__call__(*args, **kwargs)
#     935 else:
# --> 936     outputs = super().__call__(*args, **kwargs)
#     937 # Change the layout for the layer output if needed.
#     938 # This is useful for relayout intermediate tensor in the model
#     939 # to achieve the optimal performance.
#     940 distribution = distribution_lib.distribution()
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/backend/torch/layer.py:41, in TorchLayer.forward(self, *args, **kwargs)
#      40 def forward(self, *args, **kwargs):
# ---> 41     return Operation.__call__(self, *args, **kwargs)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/ops/operation.py:58, in Operation.__call__(self, *args, **kwargs)
#      53                 call_fn = self.call
#      54     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      55         call_fn,
#      56         object_name=(f"{self.__class__.__name__}.call()"),
#      57     )
# ---> 58     return call_fn(*args, **kwargs)
#      60 # Plain flow.
#      61 if any_symbolic_tensors(args, kwargs):
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/utils/torch_utils.py:123, in TorchModuleWrapper.call(self, training, *args, **kwargs)
#     121 else:
#     122     self.train()
# --> 123 return self.module(*args, **kwargs)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/layers/layer.py:936, in Layer.__call__(self, *args, **kwargs)
#     934         outputs = super().__call__(*args, **kwargs)
#     935 else:
# --> 936     outputs = super().__call__(*args, **kwargs)
#     937 # Change the layout for the layer output if needed.
#     938 # This is useful for relayout intermediate tensor in the model
#     939 # to achieve the optimal performance.
#     940 distribution = distribution_lib.distribution()
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/backend/torch/layer.py:41, in TorchLayer.forward(self, *args, **kwargs)
#      40 def forward(self, *args, **kwargs):
# ---> 41     return Operation.__call__(self, *args, **kwargs)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/ops/operation.py:58, in Operation.__call__(self, *args, **kwargs)
#      53                 call_fn = self.call
#      54     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      55         call_fn,
#      56         object_name=(f"{self.__class__.__name__}.call()"),
#      57     )
# ---> 58     return call_fn(*args, **kwargs)
#      60 # Plain flow.
#      61 if any_symbolic_tensors(args, kwargs):
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/PQuant/MDMM/src/pquant/pruning_methods/mdmm.py:71, in Constraint.call(self, weight)
#      69     ascent_lmbda = self.lmbda + lmbda_step
#      70     self.lmbda.assign_add(lmbda_step)
# ---> 71     self.prev_infs.assign(infeasibility)
#      73 l_term =  ascent_lmbda * infeasibility
#      74 damp_term = self.damping * ops.square(infeasibility) / 2
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/backend/common/variables.py:288, in Variable.assign(self, value)
#     286     scope.add_update((self, value))
#     287 else:
# --> 288     self._direct_assign(value)
#     289 return value
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/keras/src/backend/torch/core.py:113, in Variable._direct_assign(self, value)
#     112 def _direct_assign(self, value):
# --> 113     with torch.no_grad():
#     114         self.value.copy_(value)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/autograd/grad_mode.py:83, in no_grad.__exit__(self, exc_type, exc_value, traceback)
#      82 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
# ---> 83     torch.set_grad_enabled(self.prev)
#
# File /depot/cms/conda_envs/das214/pquant-gpu-env/lib/python3.10/site-packages/torch/autograd/grad_mode.py:183, in set_grad_enabled.__init__(self, mode)
#     182 def __init__(self, mode: bool) -> None:
# --> 183     self.prev = torch.is_grad_enabled()
#     184     torch._C._set_grad_enabled(mode)
#     185     self.mode = mode
#
# KeyboardInterrupt:

# %%
#print layers and lmbda weights in the model

for name, layer in model.named_modules():
    if hasattr(layer, "lmbda"):
        print(f"Layer: {name}, lmbda: {layer.lmbda}")

# %%
import numpy as np
from pquant import remove_pruning_from_model
import matplotlib.pyplot as plt
# Remove compression layers, leaves Quantized activations in place
model = remove_pruning_from_model(trained_model, config)

# Plot remaining weights
names = []
remaining = []
total_w = []
nonzeros = []
for n, m in model.named_modules():
    if isinstance(m, (torch.nn.Conv1d, torch.nn.Conv2d, torch.nn.Linear)):
        names.append(n)
        # nonzero = np.count_nonzero(m.weight.detach().cpu())
        nonzero = torch.sum(torch.abs(m.weight.detach().cpu()) > 1e-3).item()
        remaining_pct = nonzero / m.weight.numel()
        remaining.append(remaining_pct)
        total_w.append(m.weight.numel())
        nonzeros.append(nonzero)
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].bar(range(len(names)), remaining)
ax[0].set_xticks(range(len(names)))
ax[0].set_xticklabels(names)
ax[0].tick_params(axis='x', labelrotation=270)
new_ytick = []
for i in ax[0].get_yticklabels():
    ytick = f"{float(i.get_text()) * 100}%"
    new_ytick.append(ytick)
ax[0].set_yticklabels(new_ytick)
ax[0].title.set_text("Remaining weights per layer")

ax[1].bar(range(len(nonzeros)), total_w, color="lightcoral", label="total weights")
ax[1].bar(range(len(nonzeros)), nonzeros, color="steelblue", label="nonzero weights")
ax[1].set_xticks(range(len(names)))
ax[1].set_xticklabels(names)
ax[1].tick_params(axis='x', labelrotation=270)
ax[1].title.set_text("Weights per layer")
ax[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# We see from that with PDP, the number of weights goes down during training, until it reaches the target sparsity (sparsity of 80%, or ~20% remaining weights). The function that calculates the remaining weights feeds the weights through the quantizer and pruning method, and calculates the ratio between non-zero weights and all weights. However, since PDP uses a soft mask during training, the percentage of remaining weights seems to go down rather noisily (can even drop from 80% to ~20% remaining weights). The algorithm actually increases the sparsity linearly.
# During fine-tuning the mask is fixed, and turned into a mask of 0s and 1s by a simple rounding operation, so the remaining weights stay the same during each epoch.
#
# In the original paper for PDP there was no fine-tuning after the creation of the final hard mask. We have added fine-tuning here as an option that can be turned off by simply setting ```fine_tuning_epochs``` to 0 in the config file.

# %%
import numpy as np
from pquant import remove_pruning_from_model
import matplotlib.pyplot as plt
# Remove compression layers, leaves Quantized activations in place
model = remove_pruning_from_model(trained_model, config)

# Plot remaining weights
names = []
remaining = []
total_w = []
nonzeros = []
for n, m in trained_model.named_modules():
    if isinstance(m, (torch.nn.Conv1d, torch.nn.Conv2d, torch.nn.Linear)):
        names.append(n)
        nonzero = np.count_nonzero(m.weight.detach().cpu())
        remaining_pct = nonzero / m.weight.numel()
        remaining.append(remaining_pct)
        total_w.append(m.weight.numel())
        nonzeros.append(nonzero)
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].bar(range(len(names)), remaining)
ax[0].set_xticks(range(len(names)))
ax[0].set_xticklabels(names)
ax[0].tick_params(axis='x', labelrotation=270)
new_ytick = []
for i in ax[0].get_yticklabels():
    ytick = f"{float(i.get_text()) * 100}%"
    new_ytick.append(ytick)
ax[0].set_yticklabels(new_ytick)
ax[0].title.set_text("Remaining weights per layer")

ax[1].bar(range(len(nonzeros)), total_w, color="lightcoral", label="total weights")
ax[1].bar(range(len(nonzeros)), nonzeros, color="steelblue", label="nonzero weights")
ax[1].set_xticks(range(len(names)))
ax[1].set_xticklabels(names)
ax[1].tick_params(axis='x', labelrotation=270)
ax[1].title.set_text("Weights per layer")
ax[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Custom config from existing config
# Using the ```pquant/configs/config_pdp.yaml``` as base, let's customize the quantization and pruning scheme.
#
# The function we use will go through the model's layers and do the following:
#
# Quantization:
#
#         1. Looks for the names of convolutional and linear layers, as well as names of the activations (layer type activations and functional types)
#         2. Adds the name of the layer to the layer_specific list, along with a default quantization scheme of 0 and 7 for weight and bias (if bias is not None)
#
# Pruning:
#
#         1. Looks for convolutional and linear layers and adds their name to the disable_pruning_for_layers list.

# %%
# Base config
pruning_method = "pdp"
config = get_default_config(pruning_method)
model = torchvision.models.resnet18()


from pquant import add_default_layer_quantization_pruning_to_config
config = add_default_layer_quantization_pruning_to_config(model, config)
config

# %%
# Save config
from pquant.core.utils import write_config_to_yaml
write_config_to_yaml(config, "prune_quantize_example.yaml", sort_keys=False)

# %% [markdown]
# Now that we have the custom config, it is up to us to modify the quantization bits for each layer that will not use the default value. If a layer uses the default value it can be removed from the ```layer_specific``` list.
#
# For pruning, leave those layers to the ```disable_pruning_for_layers``` list that will not be pruned, others need to be removed from the list.

# %% [markdown]
# ## About replacing layers and activations
# Layers that can currently be compressed: ```nn.Conv1d, nn.Conv2d, nn.Linear```.
#
# Activations that can currently be automatically be replaced with a quantized variant: ```nn.ReLU, nn.Tanh```. The activations are replaced by a quantized variant, found in ```pquant.core.activations_quantizer.py```.

# %% [markdown]
# ## More about activations
# If using layer type activations, note that if you want to keep the fine-grained control over the quantization of the activation, reusing an activation layer can cause problems, as all activations will use the quantization bits set for that particular layer. To avoid this, use a separate ```nn.Tanh``` / ```nn.ReLU``` for each activation

# %% [markdown]
# ## HGQ
# To use HGQ, enable it in the config: `config["quantization_parameters"]["use_high_granularity_quantization"] = True`. Other relevant parameters to tune are `config["quantization_parameters"]["default_integer_bits"]`, `config["quantization_parameters"]["default_fractional_bits"]`, `config["quantization_parameters"]["hgq_gamma"]`.
# When using HGQ, we advice using Adam instead of SGD as an optimizer.
